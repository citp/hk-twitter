# %%
import pandas as pd

# %%
tweets_df = pd.read_pickle("timeline_tweets.pkl")
tweets_df["created_at"] = pd.to_datetime(tweets_df["created_at"])

# %%
tweets_df.hist("created_at")
# Out:
# array([[<AxesSubplot:title={'center':'created_at'}>]], dtype=object)

# %%
keywords = ["anime", "动画", "動畫"]
tweets_df[tweets_df["text"].str.contains("|".join(keywords))].hist("created_at")
# Out:
# array([[<AxesSubplot:title={'center':'created_at'}>]], dtype=object)

# %%
keywords = ["hong kong", "香港", "Hong Kong"]
tweets_df[tweets_df["text"].str.contains("|".join(keywords))].hist("created_at")
# Out:
# array([[<AxesSubplot:title={'center':'created_at'}>]], dtype=object)

# %%
keywords = ["china", "China", "中国", "中國"]
tweets_df[tweets_df["text"].str.contains("|".join(keywords))].hist("created_at")
# Out:
# array([[<AxesSubplot:title={'center':'created_at'}>]], dtype=object)

# %%
keywords = ["jinping", "Jinping", "Jin Ping", "习近平", "習近平"]
tweets_df[tweets_df["text"].str.contains("|".join(keywords))].hist("created_at")
# Out:
# array([[<AxesSubplot:title={'center':'created_at'}>]], dtype=object)
