# %%
import os
import json
import datetime
import time

from dateutil import parser
import glob
import json
from dataclasses import dataclass, field
from dacite import from_dict, Config
from typing import Optional

CREDENTIALS_FILE = "../creds.txt"

EXP = "tokyo"
USERFILE = f"../datasets/users/ia/{EXP}.json"


OUTDIR = f"../datasets/queried/{EXP}"
QUERY_RESULTS = "users.jsonl"
TWEET_QUERY_RESULTS = "tweets.jsonl"
MAX_USERS = 5000
# CONTROL = True

# if CONTROL:
#     USERDIR = f"{USERDIR}-control"
#     QUERY_RESULTS = f"control_{QUERY_RESULTS}"
#     TWEET_QUERY_RESULTS = f"control_{TWEET_QUERY_RESULTS}"

QUERY_RESULTS = os.path.join(OUTDIR, QUERY_RESULTS)
TWEET_QUERY_RESULTS = os.path.join(OUTDIR, TWEET_QUERY_RESULTS)

# %%
@dataclass
class Tweet:
    id: int
    text: str
    created_at: str
    lang: str
    source: str
    retweeted: bool

@dataclass
class User:
    id: int
    screen_name: str
    name: str
    description: Optional[str]
    location: Optional[str]
    tweets: list[Tweet] = field(default_factory=list)

# %%
# Load all files in USERDIR and read user objects
users = {}
tweets = set([])
with open(USERFILE, "r") as f:
    for line in f:
        userdata = from_dict(data_class=User, data=json.loads(line.strip()))
        if userdata.id not in users:
            users[userdata.id] = userdata
        else:
            users[userdata.id].tweets += userdata.tweets
        tweets.update([tweet.id for tweet in userdata.tweets])

# %%
len(users)
QUERY_RESULTS
# Out:
# '../datasets/queried/tokyo/users.jsonl'

# %% [markdown]
# # Twitter API

# %%
# Load Twitter API OAuth and other details

from TwitterAPI import TwitterAPI, TwitterOAuth

o = TwitterOAuth.read_file(CREDENTIALS_FILE)
api = TwitterAPI(o.consumer_key, o.consumer_secret, o.access_token_key, o.access_token_secret, api_version="2")


def batch(l, n):
    for i in range(0, len(l), n):
        yield l[i:i+n]

# %% [markdown]
# ## User Queries
#
# Here, we batch-query Tweet IDs to see if they still exist. We skip Tweet IDs for which we know the Tweeter either has a protected or non-existent account.

# %%
# Make sure we don't repeat queries to IDs we have already queried Twitter's API for!
if os.path.exists(QUERY_RESULTS):
    with open(QUERY_RESULTS, "r") as f:
        for line in f:
            line = line.strip()
            id = json.loads(line)["id"]
            if id in users:
                del users[id]

# %%
print(len(users))
# Out:
# 215219

# %%
# Send user queries to Twitter in batches of 100.
userids = list(users.keys())
user_responses = {}

for id_batch in batch(userids, 100):
    ids = ",".join([str(id) for id in id_batch])
    params = {
        "ids": ids,
        "user.fields": "id,description,location,name,protected,verified,withheld,username"
    }
    r = api.request(f"users", params)
    for item in r:
        user_responses[int(item["id"])] = item
    for id in id_batch:
        if id not in user_responses:
            user_responses[id] = "Not found"
    if r.get_quota()["remaining"] < 1:
        print("Ran into quota, sleeping for 15 mins")
        time.sleep(15*60)
    print(r.get_quota())
# Out:
# {'remaining': 899, 'limit': None, 'reset': None}
# {'remaining': 898, 'limit': None, 'reset': None}
# {'remaining': 897, 'limit': None, 'reset': None}
# {'remaining': 896, 'limit': None, 'reset': None}
# {'remaining': 895, 'limit': None, 'reset': None}
# {'remaining': 894, 'limit': None, 'reset': None}
# {'remaining': 893, 'limit': None, 'reset': None}
# {'remaining': 892, 'limit': None, 'reset': None}
# {'remaining': 891, 'limit': None, 'reset': None}
# {'remaining': 890, 'limit': None, 'reset': None}
# {'remaining': 889, 'limit': None, 'reset': None}
# {'remaining': 888, 'limit': None, 'reset': None}
# {'remaining': 887, 'limit': None, 'reset': None}
# {'remaining': 886, 'limit': None, 'reset': None}
# {'remaining': 885, 'limit': None, 'reset': None}
# {'remaining': 884, 'limit': None, 'reset': None}
# {'remaining': 883, 'limit': None, 'reset': None}
# {'remaining': 882, 'limit': None, 'reset': None}
# {'remaining': 881, 'limit': None, 'reset': None}
# {'remaining': 880, 'limit': None, 'reset': None}
# {'remaining': 879, 'limit': None, 'reset': None}
# {'remaining': 878, 'limit': None, 'reset': None}
# {'remaining': 877, 'limit': None, 'reset': None}
# {'remaining': 876, 'limit': None, 'reset': None}
# {'remaining': 875, 'limit': None, 'reset': None}
# {'remaining': 874, 'limit': None, 'reset': None}
# {'remaining': 873, 'limit': None, 'reset': None}
# {'remaining': 872, 'limit': None, 'reset': None}
# {'remaining': 871, 'limit': None, 'reset': None}
# {'remaining': 870, 'limit': None, 'reset': None}
# {'remaining': 869, 'limit': None, 'reset': None}
# {'remaining': 868, 'limit': None, 'reset': None}
# {'remaining': 867, 'limit': None, 'reset': None}
# {'remaining': 866, 'limit': None, 'reset': None}
# {'remaining': 865, 'limit': None, 'reset': None}
# {'remaining': 864, 'limit': None, 'reset': None}
# {'remaining': 863, 'limit': None, 'reset': None}
# {'remaining': 862, 'limit': None, 'reset': None}
# {'remaining': 861, 'limit': None, 'reset': None}
# {'remaining': 860, 'limit': None, 'reset': None}
# {'remaining': 859, 'limit': None, 'reset': None}
# {'remaining': 858, 'limit': None, 'reset': None}
# {'remaining': 857, 'limit': None, 'reset': None}
# {'remaining': 856, 'limit': None, 'reset': None}
# {'remaining': 855, 'limit': None, 'reset': None}
# {'remaining': 854, 'limit': None, 'reset': None}
# {'remaining': 853, 'limit': None, 'reset': None}
# {'remaining': 852, 'limit': None, 'reset': None}
# {'remaining': 851, 'limit': None, 'reset': None}
# {'remaining': 850, 'limit': None, 'reset': None}
# {'remaining': 849, 'limit': None, 'reset': None}
# {'remaining': 848, 'limit': None, 'reset': None}
# {'remaining': 847, 'limit': None, 'reset': None}
# {'remaining': 846, 'limit': None, 'reset': None}
# {'remaining': 845, 'limit': None, 'reset': None}
# {'remaining': 844, 'limit': None, 'reset': None}
# {'remaining': 843, 'limit': None, 'reset': None}
# {'remaining': 842, 'limit': None, 'reset': None}
# {'remaining': 841, 'limit': None, 'reset': None}
# {'remaining': 840, 'limit': None, 'reset': None}
# {'remaining': 839, 'limit': None, 'reset': None}
# {'remaining': 838, 'limit': None, 'reset': None}
# {'remaining': 837, 'limit': None, 'reset': None}
# {'remaining': 836, 'limit': None, 'reset': None}
# {'remaining': 835, 'limit': None, 'reset': None}
# {'remaining': 834, 'limit': None, 'reset': None}
# {'remaining': 833, 'limit': None, 'reset': None}
# {'remaining': 832, 'limit': None, 'reset': None}
# {'remaining': 831, 'limit': None, 'reset': None}
# {'remaining': 830, 'limit': None, 'reset': None}
# {'remaining': 829, 'limit': None, 'reset': None}
# {'remaining': 828, 'limit': None, 'reset': None}
# {'remaining': 827, 'limit': None, 'reset': None}
# {'remaining': 826, 'limit': None, 'reset': None}
# {'remaining': 825, 'limit': None, 'reset': None}
# {'remaining': 824, 'limit': None, 'reset': None}
# {'remaining': 823, 'limit': None, 'reset': None}
# {'remaining': 822, 'limit': None, 'reset': None}
# {'remaining': 821, 'limit': None, 'reset': None}
# {'remaining': 820, 'limit': None, 'reset': None}
# {'remaining': 819, 'limit': None, 'reset': None}
# {'remaining': 818, 'limit': None, 'reset': None}
# {'remaining': 817, 'limit': None, 'reset': None}
# {'remaining': 816, 'limit': None, 'reset': None}
# {'remaining': 815, 'limit': None, 'reset': None}
# {'remaining': 814, 'limit': None, 'reset': None}
# {'remaining': 813, 'limit': None, 'reset': None}
# {'remaining': 812, 'limit': None, 'reset': None}
# {'remaining': 811, 'limit': None, 'reset': None}
# {'remaining': 810, 'limit': None, 'reset': None}
# {'remaining': 809, 'limit': None, 'reset': None}
# {'remaining': 808, 'limit': None, 'reset': None}
# {'remaining': 807, 'limit': None, 'reset': None}
# {'remaining': 806, 'limit': None, 'reset': None}
# {'remaining': 805, 'limit': None, 'reset': None}
# {'remaining': 804, 'limit': None, 'reset': None}
# {'remaining': 803, 'limit': None, 'reset': None}
# {'remaining': 802, 'limit': None, 'reset': None}
# {'remaining': 801, 'limit': None, 'reset': None}
# {'remaining': 800, 'limit': None, 'reset': None}
# {'remaining': 799, 'limit': None, 'reset': None}
# {'remaining': 798, 'limit': None, 'reset': None}
# {'remaining': 797, 'limit': None, 'reset': None}
# {'remaining': 796, 'limit': None, 'reset': None}
# {'remaining': 795, 'limit': None, 'reset': None}
# {'remaining': 794, 'limit': None, 'reset': None}
# {'remaining': 793, 'limit': None, 'reset': None}
# {'remaining': 792, 'limit': None, 'reset': None}
# {'remaining': 791, 'limit': None, 'reset': None}
# {'remaining': 790, 'limit': None, 'reset': None}
# {'remaining': 789, 'limit': None, 'reset': None}
# {'remaining': 788, 'limit': None, 'reset': None}
# {'remaining': 787, 'limit': None, 'reset': None}
# {'remaining': 786, 'limit': None, 'reset': None}
# {'remaining': 785, 'limit': None, 'reset': None}
# {'remaining': 784, 'limit': None, 'reset': None}
# {'remaining': 783, 'limit': None, 'reset': None}
# {'remaining': 782, 'limit': None, 'reset': None}
# {'remaining': 781, 'limit': None, 'reset': None}
# {'remaining': 780, 'limit': None, 'reset': None}
# {'remaining': 779, 'limit': None, 'reset': None}
# {'remaining': 778, 'limit': None, 'reset': None}
# {'remaining': 777, 'limit': None, 'reset': None}
# {'remaining': 776, 'limit': None, 'reset': None}
# {'remaining': 775, 'limit': None, 'reset': None}
# {'remaining': 774, 'limit': None, 'reset': None}
# {'remaining': 773, 'limit': None, 'reset': None}
# {'remaining': 772, 'limit': None, 'reset': None}
# {'remaining': 771, 'limit': None, 'reset': None}
# {'remaining': 770, 'limit': None, 'reset': None}
# {'remaining': 769, 'limit': None, 'reset': None}
# {'remaining': 768, 'limit': None, 'reset': None}
# {'remaining': 767, 'limit': None, 'reset': None}
# {'remaining': 766, 'limit': None, 'reset': None}
# {'remaining': 765, 'limit': None, 'reset': None}
# {'remaining': 764, 'limit': None, 'reset': None}
# {'remaining': 763, 'limit': None, 'reset': None}
# {'remaining': 762, 'limit': None, 'reset': None}
# {'remaining': 761, 'limit': None, 'reset': None}
# {'remaining': 760, 'limit': None, 'reset': None}
# {'remaining': 759, 'limit': None, 'reset': None}
# {'remaining': 758, 'limit': None, 'reset': None}
# {'remaining': 757, 'limit': None, 'reset': None}
# {'remaining': 756, 'limit': None, 'reset': None}
# {'remaining': 755, 'limit': None, 'reset': None}
# {'remaining': 754, 'limit': None, 'reset': None}
# {'remaining': 753, 'limit': None, 'reset': None}
# {'remaining': 752, 'limit': None, 'reset': None}
# {'remaining': 751, 'limit': None, 'reset': None}
# {'remaining': 750, 'limit': None, 'reset': None}
# {'remaining': 749, 'limit': None, 'reset': None}
# {'remaining': 748, 'limit': None, 'reset': None}
# {'remaining': 747, 'limit': None, 'reset': None}
# {'remaining': 746, 'limit': None, 'reset': None}
# {'remaining': 745, 'limit': None, 'reset': None}
# {'remaining': 744, 'limit': None, 'reset': None}
# {'remaining': 743, 'limit': None, 'reset': None}
# {'remaining': 742, 'limit': None, 'reset': None}
# {'remaining': 741, 'limit': None, 'reset': None}
# {'remaining': 740, 'limit': None, 'reset': None}
# {'remaining': 739, 'limit': None, 'reset': None}
# {'remaining': 738, 'limit': None, 'reset': None}
# {'remaining': 737, 'limit': None, 'reset': None}
# {'remaining': 736, 'limit': None, 'reset': None}
# {'remaining': 735, 'limit': None, 'reset': None}
# {'remaining': 734, 'limit': None, 'reset': None}
# {'remaining': 733, 'limit': None, 'reset': None}
# {'remaining': 732, 'limit': None, 'reset': None}
# {'remaining': 731, 'limit': None, 'reset': None}
# {'remaining': 730, 'limit': None, 'reset': None}
# {'remaining': 729, 'limit': None, 'reset': None}
# {'remaining': 728, 'limit': None, 'reset': None}
# {'remaining': 727, 'limit': None, 'reset': None}
# {'remaining': 726, 'limit': None, 'reset': None}
# {'remaining': 725, 'limit': None, 'reset': None}
# {'remaining': 724, 'limit': None, 'reset': None}
# {'remaining': 723, 'limit': None, 'reset': None}
# {'remaining': 722, 'limit': None, 'reset': None}
# {'remaining': 721, 'limit': None, 'reset': None}
# {'remaining': 720, 'limit': None, 'reset': None}
# {'remaining': 719, 'limit': None, 'reset': None}
# {'remaining': 718, 'limit': None, 'reset': None}
# {'remaining': 717, 'limit': None, 'reset': None}
# {'remaining': 716, 'limit': None, 'reset': None}
# {'remaining': 715, 'limit': None, 'reset': None}
# {'remaining': 714, 'limit': None, 'reset': None}
# {'remaining': 713, 'limit': None, 'reset': None}
# {'remaining': 712, 'limit': None, 'reset': None}
# {'remaining': 711, 'limit': None, 'reset': None}
# {'remaining': 710, 'limit': None, 'reset': None}
# {'remaining': 709, 'limit': None, 'reset': None}
# {'remaining': 708, 'limit': None, 'reset': None}
# {'remaining': 707, 'limit': None, 'reset': None}
# {'remaining': 706, 'limit': None, 'reset': None}
# {'remaining': 705, 'limit': None, 'reset': None}
# {'remaining': 704, 'limit': None, 'reset': None}
# {'remaining': 703, 'limit': None, 'reset': None}
# {'remaining': 702, 'limit': None, 'reset': None}
# {'remaining': 701, 'limit': None, 'reset': None}
# {'remaining': 700, 'limit': None, 'reset': None}
# {'remaining': 699, 'limit': None, 'reset': None}
# {'remaining': 698, 'limit': None, 'reset': None}
# {'remaining': 697, 'limit': None, 'reset': None}
# {'remaining': 696, 'limit': None, 'reset': None}
# {'remaining': 695, 'limit': None, 'reset': None}
# {'remaining': 694, 'limit': None, 'reset': None}
# {'remaining': 693, 'limit': None, 'reset': None}
# {'remaining': 692, 'limit': None, 'reset': None}
# {'remaining': 691, 'limit': None, 'reset': None}
# {'remaining': 690, 'limit': None, 'reset': None}
# {'remaining': 689, 'limit': None, 'reset': None}
# {'remaining': 688, 'limit': None, 'reset': None}
# {'remaining': 687, 'limit': None, 'reset': None}
# {'remaining': 686, 'limit': None, 'reset': None}
# {'remaining': 685, 'limit': None, 'reset': None}
# {'remaining': 684, 'limit': None, 'reset': None}
# {'remaining': 683, 'limit': None, 'reset': None}
# {'remaining': 682, 'limit': None, 'reset': None}
# {'remaining': 681, 'limit': None, 'reset': None}
# {'remaining': 680, 'limit': None, 'reset': None}
# {'remaining': 679, 'limit': None, 'reset': None}
# {'remaining': 678, 'limit': None, 'reset': None}
# {'remaining': 677, 'limit': None, 'reset': None}
# {'remaining': 676, 'limit': None, 'reset': None}
# {'remaining': 675, 'limit': None, 'reset': None}
# {'remaining': 674, 'limit': None, 'reset': None}
# {'remaining': 673, 'limit': None, 'reset': None}
# {'remaining': 672, 'limit': None, 'reset': None}
# {'remaining': 671, 'limit': None, 'reset': None}
# {'remaining': 670, 'limit': None, 'reset': None}
# {'remaining': 669, 'limit': None, 'reset': None}
# {'remaining': 668, 'limit': None, 'reset': None}
# {'remaining': 667, 'limit': None, 'reset': None}
# {'remaining': 666, 'limit': None, 'reset': None}
# {'remaining': 665, 'limit': None, 'reset': None}
# {'remaining': 664, 'limit': None, 'reset': None}
# {'remaining': 663, 'limit': None, 'reset': None}
# {'remaining': 662, 'limit': None, 'reset': None}
# {'remaining': 661, 'limit': None, 'reset': None}
# {'remaining': 660, 'limit': None, 'reset': None}
# {'remaining': 659, 'limit': None, 'reset': None}
# {'remaining': 658, 'limit': None, 'reset': None}
# {'remaining': 657, 'limit': None, 'reset': None}
# {'remaining': 656, 'limit': None, 'reset': None}
# {'remaining': 655, 'limit': None, 'reset': None}
# {'remaining': 654, 'limit': None, 'reset': None}
# {'remaining': 653, 'limit': None, 'reset': None}
# {'remaining': 652, 'limit': None, 'reset': None}
# {'remaining': 651, 'limit': None, 'reset': None}
# {'remaining': 650, 'limit': None, 'reset': None}
# {'remaining': 649, 'limit': None, 'reset': None}
# {'remaining': 648, 'limit': None, 'reset': None}
# {'remaining': 647, 'limit': None, 'reset': None}
# {'remaining': 646, 'limit': None, 'reset': None}
# {'remaining': 645, 'limit': None, 'reset': None}
# {'remaining': 644, 'limit': None, 'reset': None}
# {'remaining': 643, 'limit': None, 'reset': None}
# {'remaining': 642, 'limit': None, 'reset': None}
# {'remaining': 641, 'limit': None, 'reset': None}
# {'remaining': 640, 'limit': None, 'reset': None}
# {'remaining': 639, 'limit': None, 'reset': None}
# {'remaining': 638, 'limit': None, 'reset': None}
# {'remaining': 637, 'limit': None, 'reset': None}
# {'remaining': 636, 'limit': None, 'reset': None}
# {'remaining': 635, 'limit': None, 'reset': None}
# {'remaining': 634, 'limit': None, 'reset': None}
# {'remaining': 633, 'limit': None, 'reset': None}
# {'remaining': 632, 'limit': None, 'reset': None}
# {'remaining': 631, 'limit': None, 'reset': None}
# {'remaining': 630, 'limit': None, 'reset': None}
# {'remaining': 629, 'limit': None, 'reset': None}
# {'remaining': 628, 'limit': None, 'reset': None}
# {'remaining': 627, 'limit': None, 'reset': None}
# {'remaining': 626, 'limit': None, 'reset': None}
# {'remaining': 625, 'limit': None, 'reset': None}
# {'remaining': 624, 'limit': None, 'reset': None}
# {'remaining': 623, 'limit': None, 'reset': None}
# {'remaining': 622, 'limit': None, 'reset': None}
# {'remaining': 621, 'limit': None, 'reset': None}
# {'remaining': 620, 'limit': None, 'reset': None}
# {'remaining': 619, 'limit': None, 'reset': None}
# {'remaining': 618, 'limit': None, 'reset': None}
# {'remaining': 617, 'limit': None, 'reset': None}
# {'remaining': 616, 'limit': None, 'reset': None}
# {'remaining': 615, 'limit': None, 'reset': None}
# {'remaining': 614, 'limit': None, 'reset': None}
# {'remaining': 613, 'limit': None, 'reset': None}
# {'remaining': 612, 'limit': None, 'reset': None}
# {'remaining': 611, 'limit': None, 'reset': None}
# {'remaining': 610, 'limit': None, 'reset': None}
# {'remaining': 609, 'limit': None, 'reset': None}
# {'remaining': 608, 'limit': None, 'reset': None}
# {'remaining': 607, 'limit': None, 'reset': None}
# {'remaining': 606, 'limit': None, 'reset': None}
# {'remaining': 605, 'limit': None, 'reset': None}
# {'remaining': 604, 'limit': None, 'reset': None}
# {'remaining': 603, 'limit': None, 'reset': None}
# {'remaining': 602, 'limit': None, 'reset': None}
# {'remaining': 601, 'limit': None, 'reset': None}
# {'remaining': 600, 'limit': None, 'reset': None}
# {'remaining': 599, 'limit': None, 'reset': None}
# {'remaining': 598, 'limit': None, 'reset': None}
# {'remaining': 597, 'limit': None, 'reset': None}
# {'remaining': 596, 'limit': None, 'reset': None}
# {'remaining': 595, 'limit': None, 'reset': None}
# {'remaining': 594, 'limit': None, 'reset': None}
# {'remaining': 593, 'limit': None, 'reset': None}
# {'remaining': 592, 'limit': None, 'reset': None}
# {'remaining': 591, 'limit': None, 'reset': None}
# {'remaining': 590, 'limit': None, 'reset': None}
# {'remaining': 589, 'limit': None, 'reset': None}
# {'remaining': 588, 'limit': None, 'reset': None}
# {'remaining': 587, 'limit': None, 'reset': None}
# {'remaining': 586, 'limit': None, 'reset': None}
# {'remaining': 585, 'limit': None, 'reset': None}
# {'remaining': 584, 'limit': None, 'reset': None}
# {'remaining': 583, 'limit': None, 'reset': None}
# {'remaining': 582, 'limit': None, 'reset': None}
# {'remaining': 581, 'limit': None, 'reset': None}
# {'remaining': 580, 'limit': None, 'reset': None}
# {'remaining': 579, 'limit': None, 'reset': None}
# {'remaining': 578, 'limit': None, 'reset': None}
# {'remaining': 577, 'limit': None, 'reset': None}
# {'remaining': 576, 'limit': None, 'reset': None}
# {'remaining': 575, 'limit': None, 'reset': None}
# {'remaining': 574, 'limit': None, 'reset': None}
# {'remaining': 573, 'limit': None, 'reset': None}
# {'remaining': 572, 'limit': None, 'reset': None}
# {'remaining': 571, 'limit': None, 'reset': None}
# {'remaining': 570, 'limit': None, 'reset': None}
# {'remaining': 569, 'limit': None, 'reset': None}
# {'remaining': 568, 'limit': None, 'reset': None}
# {'remaining': 567, 'limit': None, 'reset': None}
# {'remaining': 566, 'limit': None, 'reset': None}
# {'remaining': 565, 'limit': None, 'reset': None}
# {'remaining': 564, 'limit': None, 'reset': None}
# {'remaining': 563, 'limit': None, 'reset': None}
# {'remaining': 562, 'limit': None, 'reset': None}
# {'remaining': 561, 'limit': None, 'reset': None}
# {'remaining': 560, 'limit': None, 'reset': None}
# {'remaining': 559, 'limit': None, 'reset': None}
# {'remaining': 558, 'limit': None, 'reset': None}
# {'remaining': 557, 'limit': None, 'reset': None}
# {'remaining': 556, 'limit': None, 'reset': None}
# {'remaining': 555, 'limit': None, 'reset': None}
# {'remaining': 554, 'limit': None, 'reset': None}
# {'remaining': 553, 'limit': None, 'reset': None}
# {'remaining': 552, 'limit': None, 'reset': None}
# {'remaining': 551, 'limit': None, 'reset': None}
# {'remaining': 550, 'limit': None, 'reset': None}
# {'remaining': 549, 'limit': None, 'reset': None}
# {'remaining': 548, 'limit': None, 'reset': None}
# {'remaining': 547, 'limit': None, 'reset': None}
# {'remaining': 546, 'limit': None, 'reset': None}
# {'remaining': 545, 'limit': None, 'reset': None}
# {'remaining': 544, 'limit': None, 'reset': None}
# {'remaining': 543, 'limit': None, 'reset': None}
# {'remaining': 542, 'limit': None, 'reset': None}
# {'remaining': 541, 'limit': None, 'reset': None}
# {'remaining': 540, 'limit': None, 'reset': None}
# {'remaining': 539, 'limit': None, 'reset': None}
# {'remaining': 538, 'limit': None, 'reset': None}
# {'remaining': 537, 'limit': None, 'reset': None}
# {'remaining': 536, 'limit': None, 'reset': None}
# {'remaining': 535, 'limit': None, 'reset': None}
# {'remaining': 534, 'limit': None, 'reset': None}
# {'remaining': 533, 'limit': None, 'reset': None}
# {'remaining': 532, 'limit': None, 'reset': None}
# {'remaining': 531, 'limit': None, 'reset': None}
# {'remaining': 530, 'limit': None, 'reset': None}
# {'remaining': 529, 'limit': None, 'reset': None}
# {'remaining': 528, 'limit': None, 'reset': None}
# {'remaining': 527, 'limit': None, 'reset': None}
# {'remaining': 526, 'limit': None, 'reset': None}
# {'remaining': 525, 'limit': None, 'reset': None}
# {'remaining': 524, 'limit': None, 'reset': None}
# {'remaining': 523, 'limit': None, 'reset': None}
# {'remaining': 522, 'limit': None, 'reset': None}
# {'remaining': 521, 'limit': None, 'reset': None}
# {'remaining': 520, 'limit': None, 'reset': None}
# {'remaining': 519, 'limit': None, 'reset': None}
# {'remaining': 518, 'limit': None, 'reset': None}
# {'remaining': 517, 'limit': None, 'reset': None}
# {'remaining': 516, 'limit': None, 'reset': None}
# {'remaining': 515, 'limit': None, 'reset': None}
# {'remaining': 514, 'limit': None, 'reset': None}
# {'remaining': 513, 'limit': None, 'reset': None}
# {'remaining': 512, 'limit': None, 'reset': None}
# {'remaining': 511, 'limit': None, 'reset': None}
# {'remaining': 510, 'limit': None, 'reset': None}
# {'remaining': 509, 'limit': None, 'reset': None}
# {'remaining': 508, 'limit': None, 'reset': None}
# {'remaining': 507, 'limit': None, 'reset': None}
# {'remaining': 506, 'limit': None, 'reset': None}
# {'remaining': 505, 'limit': None, 'reset': None}
# {'remaining': 504, 'limit': None, 'reset': None}
# {'remaining': 503, 'limit': None, 'reset': None}
# {'remaining': 502, 'limit': None, 'reset': None}
# {'remaining': 501, 'limit': None, 'reset': None}
# {'remaining': 500, 'limit': None, 'reset': None}
# {'remaining': 499, 'limit': None, 'reset': None}
# {'remaining': 498, 'limit': None, 'reset': None}
# {'remaining': 497, 'limit': None, 'reset': None}
# {'remaining': 496, 'limit': None, 'reset': None}
# {'remaining': 495, 'limit': None, 'reset': None}
# {'remaining': 494, 'limit': None, 'reset': None}
# {'remaining': 493, 'limit': None, 'reset': None}
# {'remaining': 492, 'limit': None, 'reset': None}
# {'remaining': 491, 'limit': None, 'reset': None}
# {'remaining': 490, 'limit': None, 'reset': None}
# {'remaining': 489, 'limit': None, 'reset': None}
# {'remaining': 488, 'limit': None, 'reset': None}
# {'remaining': 487, 'limit': None, 'reset': None}
# {'remaining': 486, 'limit': None, 'reset': None}
# {'remaining': 485, 'limit': None, 'reset': None}
# {'remaining': 484, 'limit': None, 'reset': None}
# {'remaining': 483, 'limit': None, 'reset': None}
# {'remaining': 482, 'limit': None, 'reset': None}
# {'remaining': 481, 'limit': None, 'reset': None}
# {'remaining': 480, 'limit': None, 'reset': None}
# {'remaining': 479, 'limit': None, 'reset': None}
# {'remaining': 478, 'limit': None, 'reset': None}
# {'remaining': 477, 'limit': None, 'reset': None}
# {'remaining': 476, 'limit': None, 'reset': None}
# {'remaining': 475, 'limit': None, 'reset': None}
# {'remaining': 474, 'limit': None, 'reset': None}
# {'remaining': 473, 'limit': None, 'reset': None}
# {'remaining': 472, 'limit': None, 'reset': None}
# {'remaining': 471, 'limit': None, 'reset': None}
# {'remaining': 470, 'limit': None, 'reset': None}
# {'remaining': 469, 'limit': None, 'reset': None}
# {'remaining': 468, 'limit': None, 'reset': None}
# {'remaining': 467, 'limit': None, 'reset': None}
# {'remaining': 466, 'limit': None, 'reset': None}
# {'remaining': 465, 'limit': None, 'reset': None}
# {'remaining': 464, 'limit': None, 'reset': None}
# {'remaining': 463, 'limit': None, 'reset': None}
# {'remaining': 462, 'limit': None, 'reset': None}
# {'remaining': 461, 'limit': None, 'reset': None}
# {'remaining': 460, 'limit': None, 'reset': None}
# {'remaining': 459, 'limit': None, 'reset': None}
# {'remaining': 458, 'limit': None, 'reset': None}
# {'remaining': 457, 'limit': None, 'reset': None}
# {'remaining': 456, 'limit': None, 'reset': None}
# {'remaining': 455, 'limit': None, 'reset': None}
# {'remaining': 454, 'limit': None, 'reset': None}
# {'remaining': 453, 'limit': None, 'reset': None}
# {'remaining': 452, 'limit': None, 'reset': None}
# {'remaining': 451, 'limit': None, 'reset': None}
# {'remaining': 450, 'limit': None, 'reset': None}
# {'remaining': 449, 'limit': None, 'reset': None}
# {'remaining': 448, 'limit': None, 'reset': None}
# {'remaining': 447, 'limit': None, 'reset': None}
# {'remaining': 446, 'limit': None, 'reset': None}
# {'remaining': 445, 'limit': None, 'reset': None}
# {'remaining': 444, 'limit': None, 'reset': None}
# {'remaining': 443, 'limit': None, 'reset': None}
# {'remaining': 442, 'limit': None, 'reset': None}
# {'remaining': 441, 'limit': None, 'reset': None}
# {'remaining': 440, 'limit': None, 'reset': None}
# {'remaining': 439, 'limit': None, 'reset': None}
# {'remaining': 438, 'limit': None, 'reset': None}
# {'remaining': 437, 'limit': None, 'reset': None}
# {'remaining': 436, 'limit': None, 'reset': None}
# {'remaining': 435, 'limit': None, 'reset': None}
# {'remaining': 434, 'limit': None, 'reset': None}
# {'remaining': 433, 'limit': None, 'reset': None}
# {'remaining': 432, 'limit': None, 'reset': None}
# {'remaining': 431, 'limit': None, 'reset': None}
# {'remaining': 430, 'limit': None, 'reset': None}
# {'remaining': 429, 'limit': None, 'reset': None}
# {'remaining': 428, 'limit': None, 'reset': None}
# {'remaining': 427, 'limit': None, 'reset': None}
# {'remaining': 426, 'limit': None, 'reset': None}
# {'remaining': 425, 'limit': None, 'reset': None}
# {'remaining': 424, 'limit': None, 'reset': None}
# {'remaining': 423, 'limit': None, 'reset': None}
# {'remaining': 422, 'limit': None, 'reset': None}
# {'remaining': 421, 'limit': None, 'reset': None}
# {'remaining': 420, 'limit': None, 'reset': None}
# {'remaining': 419, 'limit': None, 'reset': None}
# {'remaining': 418, 'limit': None, 'reset': None}
# {'remaining': 417, 'limit': None, 'reset': None}
# {'remaining': 416, 'limit': None, 'reset': None}
# {'remaining': 415, 'limit': None, 'reset': None}
# {'remaining': 414, 'limit': None, 'reset': None}
# {'remaining': 413, 'limit': None, 'reset': None}
# {'remaining': 412, 'limit': None, 'reset': None}
# {'remaining': 411, 'limit': None, 'reset': None}
# {'remaining': 410, 'limit': None, 'reset': None}
# {'remaining': 409, 'limit': None, 'reset': None}
# {'remaining': 408, 'limit': None, 'reset': None}
# {'remaining': 407, 'limit': None, 'reset': None}
# {'remaining': 406, 'limit': None, 'reset': None}
# {'remaining': 405, 'limit': None, 'reset': None}
# {'remaining': 404, 'limit': None, 'reset': None}
# {'remaining': 403, 'limit': None, 'reset': None}
# {'remaining': 402, 'limit': None, 'reset': None}
# {'remaining': 401, 'limit': None, 'reset': None}
# {'remaining': 400, 'limit': None, 'reset': None}
# {'remaining': 399, 'limit': None, 'reset': None}
# {'remaining': 398, 'limit': None, 'reset': None}
# {'remaining': 397, 'limit': None, 'reset': None}
# {'remaining': 396, 'limit': None, 'reset': None}
# {'remaining': 395, 'limit': None, 'reset': None}
# {'remaining': 394, 'limit': None, 'reset': None}
# {'remaining': 393, 'limit': None, 'reset': None}
# {'remaining': 392, 'limit': None, 'reset': None}
# {'remaining': 391, 'limit': None, 'reset': None}
# {'remaining': 390, 'limit': None, 'reset': None}
# {'remaining': 389, 'limit': None, 'reset': None}
# {'remaining': 388, 'limit': None, 'reset': None}
# {'remaining': 387, 'limit': None, 'reset': None}
# {'remaining': 386, 'limit': None, 'reset': None}
# {'remaining': 385, 'limit': None, 'reset': None}
# {'remaining': 384, 'limit': None, 'reset': None}
# {'remaining': 383, 'limit': None, 'reset': None}
# {'remaining': 382, 'limit': None, 'reset': None}
# {'remaining': 381, 'limit': None, 'reset': None}
# {'remaining': 380, 'limit': None, 'reset': None}
# {'remaining': 379, 'limit': None, 'reset': None}
# {'remaining': 378, 'limit': None, 'reset': None}
# {'remaining': 377, 'limit': None, 'reset': None}
# {'remaining': 376, 'limit': None, 'reset': None}
# {'remaining': 375, 'limit': None, 'reset': None}
# {'remaining': 374, 'limit': None, 'reset': None}
# {'remaining': 373, 'limit': None, 'reset': None}
# {'remaining': 372, 'limit': None, 'reset': None}
# {'remaining': 371, 'limit': None, 'reset': None}
# {'remaining': 370, 'limit': None, 'reset': None}
# {'remaining': 369, 'limit': None, 'reset': None}
# {'remaining': 368, 'limit': None, 'reset': None}
# {'remaining': 367, 'limit': None, 'reset': None}
# {'remaining': 366, 'limit': None, 'reset': None}
# {'remaining': 365, 'limit': None, 'reset': None}
# {'remaining': 364, 'limit': None, 'reset': None}
# {'remaining': 363, 'limit': None, 'reset': None}
# {'remaining': 362, 'limit': None, 'reset': None}
# {'remaining': 361, 'limit': None, 'reset': None}
# {'remaining': 360, 'limit': None, 'reset': None}
# {'remaining': 359, 'limit': None, 'reset': None}
# {'remaining': 358, 'limit': None, 'reset': None}
# {'remaining': 357, 'limit': None, 'reset': None}
# {'remaining': 356, 'limit': None, 'reset': None}
# {'remaining': 355, 'limit': None, 'reset': None}
# {'remaining': 354, 'limit': None, 'reset': None}
# {'remaining': 353, 'limit': None, 'reset': None}
# {'remaining': 352, 'limit': None, 'reset': None}
# {'remaining': 351, 'limit': None, 'reset': None}
# {'remaining': 350, 'limit': None, 'reset': None}
# {'remaining': 349, 'limit': None, 'reset': None}
# {'remaining': 348, 'limit': None, 'reset': None}
# {'remaining': 347, 'limit': None, 'reset': None}
# {'remaining': 346, 'limit': None, 'reset': None}
# {'remaining': 345, 'limit': None, 'reset': None}
# {'remaining': 344, 'limit': None, 'reset': None}
# {'remaining': 343, 'limit': None, 'reset': None}
# {'remaining': 342, 'limit': None, 'reset': None}
# {'remaining': 341, 'limit': None, 'reset': None}
# {'remaining': 340, 'limit': None, 'reset': None}
# {'remaining': 339, 'limit': None, 'reset': None}
# {'remaining': 338, 'limit': None, 'reset': None}
# {'remaining': 337, 'limit': None, 'reset': None}
# {'remaining': 336, 'limit': None, 'reset': None}
# {'remaining': 335, 'limit': None, 'reset': None}
# {'remaining': 334, 'limit': None, 'reset': None}
# {'remaining': 333, 'limit': None, 'reset': None}
# {'remaining': 332, 'limit': None, 'reset': None}
# {'remaining': 331, 'limit': None, 'reset': None}
# {'remaining': 330, 'limit': None, 'reset': None}
# {'remaining': 329, 'limit': None, 'reset': None}
# {'remaining': 328, 'limit': None, 'reset': None}
# {'remaining': 327, 'limit': None, 'reset': None}
# {'remaining': 326, 'limit': None, 'reset': None}
# {'remaining': 325, 'limit': None, 'reset': None}
# {'remaining': 324, 'limit': None, 'reset': None}
# {'remaining': 323, 'limit': None, 'reset': None}
# {'remaining': 322, 'limit': None, 'reset': None}
# {'remaining': 321, 'limit': None, 'reset': None}
# {'remaining': 320, 'limit': None, 'reset': None}
# {'remaining': 319, 'limit': None, 'reset': None}
# {'remaining': 318, 'limit': None, 'reset': None}
# {'remaining': 317, 'limit': None, 'reset': None}
# {'remaining': 316, 'limit': None, 'reset': None}
# {'remaining': 315, 'limit': None, 'reset': None}
# {'remaining': 314, 'limit': None, 'reset': None}
# {'remaining': 313, 'limit': None, 'reset': None}
# {'remaining': 312, 'limit': None, 'reset': None}
# {'remaining': 311, 'limit': None, 'reset': None}
# {'remaining': 310, 'limit': None, 'reset': None}
# {'remaining': 309, 'limit': None, 'reset': None}
# {'remaining': 308, 'limit': None, 'reset': None}
# {'remaining': 307, 'limit': None, 'reset': None}
# {'remaining': 306, 'limit': None, 'reset': None}
# {'remaining': 305, 'limit': None, 'reset': None}
# {'remaining': 304, 'limit': None, 'reset': None}
# {'remaining': 303, 'limit': None, 'reset': None}
# {'remaining': 302, 'limit': None, 'reset': None}
# {'remaining': 301, 'limit': None, 'reset': None}
# {'remaining': 300, 'limit': None, 'reset': None}
# {'remaining': 299, 'limit': None, 'reset': None}
# {'remaining': 298, 'limit': None, 'reset': None}
# {'remaining': 297, 'limit': None, 'reset': None}
# {'remaining': 296, 'limit': None, 'reset': None}
# {'remaining': 295, 'limit': None, 'reset': None}
# {'remaining': 294, 'limit': None, 'reset': None}
# {'remaining': 293, 'limit': None, 'reset': None}
# {'remaining': 292, 'limit': None, 'reset': None}
# {'remaining': 291, 'limit': None, 'reset': None}
# {'remaining': 290, 'limit': None, 'reset': None}
# {'remaining': 289, 'limit': None, 'reset': None}
# {'remaining': 288, 'limit': None, 'reset': None}
# {'remaining': 287, 'limit': None, 'reset': None}
# {'remaining': 286, 'limit': None, 'reset': None}
# {'remaining': 285, 'limit': None, 'reset': None}
# {'remaining': 284, 'limit': None, 'reset': None}
# {'remaining': 283, 'limit': None, 'reset': None}
# {'remaining': 282, 'limit': None, 'reset': None}
# {'remaining': 281, 'limit': None, 'reset': None}
# {'remaining': 280, 'limit': None, 'reset': None}
# {'remaining': 279, 'limit': None, 'reset': None}
# {'remaining': 278, 'limit': None, 'reset': None}
# {'remaining': 277, 'limit': None, 'reset': None}
# {'remaining': 276, 'limit': None, 'reset': None}
# {'remaining': 275, 'limit': None, 'reset': None}
# {'remaining': 274, 'limit': None, 'reset': None}
# {'remaining': 273, 'limit': None, 'reset': None}
# {'remaining': 272, 'limit': None, 'reset': None}
# {'remaining': 271, 'limit': None, 'reset': None}
# {'remaining': 270, 'limit': None, 'reset': None}
# {'remaining': 269, 'limit': None, 'reset': None}
# {'remaining': 268, 'limit': None, 'reset': None}
# {'remaining': 267, 'limit': None, 'reset': None}
# {'remaining': 266, 'limit': None, 'reset': None}
# {'remaining': 265, 'limit': None, 'reset': None}
# {'remaining': 264, 'limit': None, 'reset': None}
# {'remaining': 263, 'limit': None, 'reset': None}
# {'remaining': 262, 'limit': None, 'reset': None}
# {'remaining': 261, 'limit': None, 'reset': None}
# {'remaining': 260, 'limit': None, 'reset': None}
# {'remaining': 259, 'limit': None, 'reset': None}
# {'remaining': 258, 'limit': None, 'reset': None}
# {'remaining': 257, 'limit': None, 'reset': None}
# {'remaining': 256, 'limit': None, 'reset': None}
# {'remaining': 255, 'limit': None, 'reset': None}
# {'remaining': 254, 'limit': None, 'reset': None}
# {'remaining': 253, 'limit': None, 'reset': None}
# {'remaining': 252, 'limit': None, 'reset': None}
# {'remaining': 251, 'limit': None, 'reset': None}
# {'remaining': 250, 'limit': None, 'reset': None}
# {'remaining': 249, 'limit': None, 'reset': None}
# {'remaining': 248, 'limit': None, 'reset': None}
# {'remaining': 247, 'limit': None, 'reset': None}
# {'remaining': 246, 'limit': None, 'reset': None}
# {'remaining': 245, 'limit': None, 'reset': None}
# {'remaining': 244, 'limit': None, 'reset': None}
# {'remaining': 243, 'limit': None, 'reset': None}
# {'remaining': 242, 'limit': None, 'reset': None}
# {'remaining': 241, 'limit': None, 'reset': None}
# {'remaining': 240, 'limit': None, 'reset': None}
# {'remaining': 239, 'limit': None, 'reset': None}
# {'remaining': 238, 'limit': None, 'reset': None}
# {'remaining': 237, 'limit': None, 'reset': None}
# {'remaining': 236, 'limit': None, 'reset': None}
# {'remaining': 235, 'limit': None, 'reset': None}
# {'remaining': 234, 'limit': None, 'reset': None}
# {'remaining': 233, 'limit': None, 'reset': None}
# {'remaining': 232, 'limit': None, 'reset': None}
# {'remaining': 231, 'limit': None, 'reset': None}
# {'remaining': 230, 'limit': None, 'reset': None}
# {'remaining': 229, 'limit': None, 'reset': None}
# {'remaining': 228, 'limit': None, 'reset': None}
# {'remaining': 227, 'limit': None, 'reset': None}
# {'remaining': 226, 'limit': None, 'reset': None}
# {'remaining': 225, 'limit': None, 'reset': None}
# {'remaining': 224, 'limit': None, 'reset': None}
# {'remaining': 223, 'limit': None, 'reset': None}
# {'remaining': 222, 'limit': None, 'reset': None}
# {'remaining': 221, 'limit': None, 'reset': None}
# {'remaining': 220, 'limit': None, 'reset': None}
# {'remaining': 219, 'limit': None, 'reset': None}
# {'remaining': 218, 'limit': None, 'reset': None}
# {'remaining': 217, 'limit': None, 'reset': None}
# {'remaining': 216, 'limit': None, 'reset': None}
# {'remaining': 215, 'limit': None, 'reset': None}
# {'remaining': 214, 'limit': None, 'reset': None}
# {'remaining': 213, 'limit': None, 'reset': None}
# {'remaining': 212, 'limit': None, 'reset': None}
# {'remaining': 211, 'limit': None, 'reset': None}
# {'remaining': 210, 'limit': None, 'reset': None}
# {'remaining': 209, 'limit': None, 'reset': None}
# {'remaining': 208, 'limit': None, 'reset': None}
# {'remaining': 207, 'limit': None, 'reset': None}
# {'remaining': 206, 'limit': None, 'reset': None}
# {'remaining': 205, 'limit': None, 'reset': None}
# {'remaining': 204, 'limit': None, 'reset': None}
# {'remaining': 203, 'limit': None, 'reset': None}
# {'remaining': 202, 'limit': None, 'reset': None}
# {'remaining': 201, 'limit': None, 'reset': None}
# {'remaining': 200, 'limit': None, 'reset': None}
# {'remaining': 199, 'limit': None, 'reset': None}
# {'remaining': 198, 'limit': None, 'reset': None}
# {'remaining': 197, 'limit': None, 'reset': None}
# {'remaining': 196, 'limit': None, 'reset': None}
# {'remaining': 195, 'limit': None, 'reset': None}
# {'remaining': 194, 'limit': None, 'reset': None}
# {'remaining': 193, 'limit': None, 'reset': None}
# {'remaining': 192, 'limit': None, 'reset': None}
# {'remaining': 191, 'limit': None, 'reset': None}
# {'remaining': 190, 'limit': None, 'reset': None}
# {'remaining': 189, 'limit': None, 'reset': None}
# {'remaining': 188, 'limit': None, 'reset': None}
# {'remaining': 187, 'limit': None, 'reset': None}
# {'remaining': 186, 'limit': None, 'reset': None}
# {'remaining': 185, 'limit': None, 'reset': None}
# {'remaining': 184, 'limit': None, 'reset': None}
# {'remaining': 183, 'limit': None, 'reset': None}
# {'remaining': 182, 'limit': None, 'reset': None}
# {'remaining': 181, 'limit': None, 'reset': None}
# {'remaining': 180, 'limit': None, 'reset': None}
# {'remaining': 179, 'limit': None, 'reset': None}
# {'remaining': 178, 'limit': None, 'reset': None}
# {'remaining': 177, 'limit': None, 'reset': None}
# {'remaining': 176, 'limit': None, 'reset': None}
# {'remaining': 175, 'limit': None, 'reset': None}
# {'remaining': 174, 'limit': None, 'reset': None}
# {'remaining': 173, 'limit': None, 'reset': None}
# {'remaining': 172, 'limit': None, 'reset': None}
# {'remaining': 171, 'limit': None, 'reset': None}
# {'remaining': 170, 'limit': None, 'reset': None}
# {'remaining': 169, 'limit': None, 'reset': None}
# {'remaining': 168, 'limit': None, 'reset': None}
# {'remaining': 167, 'limit': None, 'reset': None}
# {'remaining': 166, 'limit': None, 'reset': None}
# {'remaining': 165, 'limit': None, 'reset': None}
# {'remaining': 164, 'limit': None, 'reset': None}
# {'remaining': 163, 'limit': None, 'reset': None}
# {'remaining': 162, 'limit': None, 'reset': None}
# {'remaining': 161, 'limit': None, 'reset': None}
# {'remaining': 160, 'limit': None, 'reset': None}
# {'remaining': 159, 'limit': None, 'reset': None}
# {'remaining': 158, 'limit': None, 'reset': None}
# {'remaining': 157, 'limit': None, 'reset': None}
# {'remaining': 156, 'limit': None, 'reset': None}
# {'remaining': 155, 'limit': None, 'reset': None}
# {'remaining': 154, 'limit': None, 'reset': None}
# {'remaining': 153, 'limit': None, 'reset': None}
# {'remaining': 152, 'limit': None, 'reset': None}
# {'remaining': 151, 'limit': None, 'reset': None}
# {'remaining': 150, 'limit': None, 'reset': None}
# {'remaining': 149, 'limit': None, 'reset': None}
# {'remaining': 148, 'limit': None, 'reset': None}
# {'remaining': 147, 'limit': None, 'reset': None}
# {'remaining': 146, 'limit': None, 'reset': None}
# {'remaining': 145, 'limit': None, 'reset': None}
# {'remaining': 144, 'limit': None, 'reset': None}
# {'remaining': 143, 'limit': None, 'reset': None}
# {'remaining': 142, 'limit': None, 'reset': None}
# {'remaining': 141, 'limit': None, 'reset': None}
# {'remaining': 140, 'limit': None, 'reset': None}
# {'remaining': 139, 'limit': None, 'reset': None}
# {'remaining': 138, 'limit': None, 'reset': None}
# {'remaining': 137, 'limit': None, 'reset': None}
# {'remaining': 136, 'limit': None, 'reset': None}
# {'remaining': 135, 'limit': None, 'reset': None}
# {'remaining': 134, 'limit': None, 'reset': None}
# {'remaining': 133, 'limit': None, 'reset': None}
# {'remaining': 132, 'limit': None, 'reset': None}
# {'remaining': 131, 'limit': None, 'reset': None}
# {'remaining': 130, 'limit': None, 'reset': None}
# {'remaining': 129, 'limit': None, 'reset': None}
# {'remaining': 128, 'limit': None, 'reset': None}
# {'remaining': 127, 'limit': None, 'reset': None}
# {'remaining': 126, 'limit': None, 'reset': None}
# {'remaining': 125, 'limit': None, 'reset': None}
# {'remaining': 124, 'limit': None, 'reset': None}
# {'remaining': 123, 'limit': None, 'reset': None}
# {'remaining': 122, 'limit': None, 'reset': None}
# {'remaining': 121, 'limit': None, 'reset': None}
# {'remaining': 120, 'limit': None, 'reset': None}
# {'remaining': 119, 'limit': None, 'reset': None}
# {'remaining': 118, 'limit': None, 'reset': None}
# {'remaining': 117, 'limit': None, 'reset': None}
# {'remaining': 116, 'limit': None, 'reset': None}
# {'remaining': 115, 'limit': None, 'reset': None}
# {'remaining': 114, 'limit': None, 'reset': None}
# {'remaining': 113, 'limit': None, 'reset': None}
# {'remaining': 112, 'limit': None, 'reset': None}
# {'remaining': 111, 'limit': None, 'reset': None}
# {'remaining': 110, 'limit': None, 'reset': None}
# {'remaining': 109, 'limit': None, 'reset': None}
# {'remaining': 108, 'limit': None, 'reset': None}
# {'remaining': 107, 'limit': None, 'reset': None}
# {'remaining': 106, 'limit': None, 'reset': None}
# {'remaining': 105, 'limit': None, 'reset': None}
# {'remaining': 104, 'limit': None, 'reset': None}
# {'remaining': 103, 'limit': None, 'reset': None}
# {'remaining': 102, 'limit': None, 'reset': None}
# {'remaining': 101, 'limit': None, 'reset': None}
# {'remaining': 100, 'limit': None, 'reset': None}
# {'remaining': 99, 'limit': None, 'reset': None}
# {'remaining': 98, 'limit': None, 'reset': None}
# {'remaining': 97, 'limit': None, 'reset': None}
# {'remaining': 96, 'limit': None, 'reset': None}
# {'remaining': 95, 'limit': None, 'reset': None}
# {'remaining': 94, 'limit': None, 'reset': None}
# {'remaining': 93, 'limit': None, 'reset': None}
# {'remaining': 92, 'limit': None, 'reset': None}
# {'remaining': 91, 'limit': None, 'reset': None}
# {'remaining': 90, 'limit': None, 'reset': None}
# {'remaining': 89, 'limit': None, 'reset': None}
# {'remaining': 88, 'limit': None, 'reset': None}
# {'remaining': 87, 'limit': None, 'reset': None}
# {'remaining': 86, 'limit': None, 'reset': None}
# {'remaining': 85, 'limit': None, 'reset': None}
# {'remaining': 84, 'limit': None, 'reset': None}
# {'remaining': 83, 'limit': None, 'reset': None}
# {'remaining': 82, 'limit': None, 'reset': None}
# {'remaining': 81, 'limit': None, 'reset': None}
# {'remaining': 80, 'limit': None, 'reset': None}
# {'remaining': 79, 'limit': None, 'reset': None}
# {'remaining': 78, 'limit': None, 'reset': None}
# {'remaining': 77, 'limit': None, 'reset': None}
# {'remaining': 76, 'limit': None, 'reset': None}
# {'remaining': 75, 'limit': None, 'reset': None}
# {'remaining': 74, 'limit': None, 'reset': None}
# {'remaining': 73, 'limit': None, 'reset': None}
# {'remaining': 72, 'limit': None, 'reset': None}
# {'remaining': 71, 'limit': None, 'reset': None}
# {'remaining': 70, 'limit': None, 'reset': None}
# {'remaining': 69, 'limit': None, 'reset': None}
# {'remaining': 68, 'limit': None, 'reset': None}
# {'remaining': 67, 'limit': None, 'reset': None}
# {'remaining': 66, 'limit': None, 'reset': None}
# {'remaining': 65, 'limit': None, 'reset': None}
# {'remaining': 64, 'limit': None, 'reset': None}
# {'remaining': 63, 'limit': None, 'reset': None}
# {'remaining': 62, 'limit': None, 'reset': None}
# {'remaining': 61, 'limit': None, 'reset': None}
# {'remaining': 60, 'limit': None, 'reset': None}
# {'remaining': 59, 'limit': None, 'reset': None}
# {'remaining': 58, 'limit': None, 'reset': None}
# {'remaining': 57, 'limit': None, 'reset': None}
# {'remaining': 56, 'limit': None, 'reset': None}
# {'remaining': 55, 'limit': None, 'reset': None}
# {'remaining': 54, 'limit': None, 'reset': None}
# {'remaining': 53, 'limit': None, 'reset': None}
# {'remaining': 52, 'limit': None, 'reset': None}
# {'remaining': 51, 'limit': None, 'reset': None}
# {'remaining': 50, 'limit': None, 'reset': None}
# {'remaining': 49, 'limit': None, 'reset': None}
# {'remaining': 48, 'limit': None, 'reset': None}
# {'remaining': 47, 'limit': None, 'reset': None}
# {'remaining': 46, 'limit': None, 'reset': None}
# {'remaining': 45, 'limit': None, 'reset': None}
# {'remaining': 44, 'limit': None, 'reset': None}
# {'remaining': 43, 'limit': None, 'reset': None}
# {'remaining': 42, 'limit': None, 'reset': None}
# {'remaining': 41, 'limit': None, 'reset': None}
# {'remaining': 40, 'limit': None, 'reset': None}
# {'remaining': 39, 'limit': None, 'reset': None}
# {'remaining': 38, 'limit': None, 'reset': None}
# {'remaining': 37, 'limit': None, 'reset': None}
# {'remaining': 36, 'limit': None, 'reset': None}
# {'remaining': 35, 'limit': None, 'reset': None}
# {'remaining': 34, 'limit': None, 'reset': None}
# {'remaining': 33, 'limit': None, 'reset': None}
# {'remaining': 32, 'limit': None, 'reset': None}
# {'remaining': 31, 'limit': None, 'reset': None}
# {'remaining': 30, 'limit': None, 'reset': None}
# {'remaining': 29, 'limit': None, 'reset': None}
# {'remaining': 28, 'limit': None, 'reset': None}
# {'remaining': 27, 'limit': None, 'reset': None}
# {'remaining': 26, 'limit': None, 'reset': None}
# {'remaining': 25, 'limit': None, 'reset': None}
# {'remaining': 24, 'limit': None, 'reset': None}
# {'remaining': 23, 'limit': None, 'reset': None}
# {'remaining': 22, 'limit': None, 'reset': None}
# {'remaining': 21, 'limit': None, 'reset': None}
# {'remaining': 20, 'limit': None, 'reset': None}
# {'remaining': 19, 'limit': None, 'reset': None}
# {'remaining': 18, 'limit': None, 'reset': None}
# {'remaining': 17, 'limit': None, 'reset': None}
# {'remaining': 16, 'limit': None, 'reset': None}
# {'remaining': 15, 'limit': None, 'reset': None}
# {'remaining': 14, 'limit': None, 'reset': None}
# {'remaining': 13, 'limit': None, 'reset': None}
# {'remaining': 12, 'limit': None, 'reset': None}
# {'remaining': 11, 'limit': None, 'reset': None}
# {'remaining': 10, 'limit': None, 'reset': None}
# {'remaining': 9, 'limit': None, 'reset': None}
# {'remaining': 8, 'limit': None, 'reset': None}
# {'remaining': 7, 'limit': None, 'reset': None}
# {'remaining': 6, 'limit': None, 'reset': None}
# {'remaining': 5, 'limit': None, 'reset': None}
# {'remaining': 4, 'limit': None, 'reset': None}
# {'remaining': 3, 'limit': None, 'reset': None}
# {'remaining': 2, 'limit': None, 'reset': None}
# {'remaining': 1, 'limit': None, 'reset': None}
# Ran into quota, sleeping for 15 mins
# {'remaining': 0, 'limit': 900, 'reset': datetime.datetime(2022, 1, 3, 10, 10, 51)}
# {'remaining': 899, 'limit': None, 'reset': None}
# {'remaining': 898, 'limit': None, 'reset': None}
# {'remaining': 897, 'limit': None, 'reset': None}
# {'remaining': 896, 'limit': None, 'reset': None}
# {'remaining': 895, 'limit': None, 'reset': None}
# {'remaining': 894, 'limit': None, 'reset': None}
# {'remaining': 893, 'limit': None, 'reset': None}
# {'remaining': 892, 'limit': None, 'reset': None}
# {'remaining': 891, 'limit': None, 'reset': None}
# {'remaining': 890, 'limit': None, 'reset': None}
# {'remaining': 889, 'limit': None, 'reset': None}
# {'remaining': 888, 'limit': None, 'reset': None}
# {'remaining': 887, 'limit': None, 'reset': None}
# {'remaining': 886, 'limit': None, 'reset': None}
# {'remaining': 885, 'limit': None, 'reset': None}
# {'remaining': 884, 'limit': None, 'reset': None}
# {'remaining': 883, 'limit': None, 'reset': None}
# {'remaining': 882, 'limit': None, 'reset': None}
# {'remaining': 881, 'limit': None, 'reset': None}
# {'remaining': 880, 'limit': None, 'reset': None}
# {'remaining': 879, 'limit': None, 'reset': None}
# {'remaining': 878, 'limit': None, 'reset': None}
# {'remaining': 877, 'limit': None, 'reset': None}
# {'remaining': 876, 'limit': None, 'reset': None}
# {'remaining': 875, 'limit': None, 'reset': None}
# {'remaining': 874, 'limit': None, 'reset': None}
# {'remaining': 873, 'limit': None, 'reset': None}
# {'remaining': 872, 'limit': None, 'reset': None}
# {'remaining': 871, 'limit': None, 'reset': None}
# {'remaining': 870, 'limit': None, 'reset': None}
# {'remaining': 869, 'limit': None, 'reset': None}
# {'remaining': 868, 'limit': None, 'reset': None}
# {'remaining': 867, 'limit': None, 'reset': None}
# {'remaining': 866, 'limit': None, 'reset': None}
# {'remaining': 865, 'limit': None, 'reset': None}
# {'remaining': 864, 'limit': None, 'reset': None}
# {'remaining': 863, 'limit': None, 'reset': None}
# {'remaining': 862, 'limit': None, 'reset': None}
# {'remaining': 861, 'limit': None, 'reset': None}
# {'remaining': 860, 'limit': None, 'reset': None}
# {'remaining': 859, 'limit': None, 'reset': None}
# {'remaining': 858, 'limit': None, 'reset': None}
# {'remaining': 857, 'limit': None, 'reset': None}
# {'remaining': 856, 'limit': None, 'reset': None}
# {'remaining': 855, 'limit': None, 'reset': None}
# {'remaining': 854, 'limit': None, 'reset': None}
# {'remaining': 853, 'limit': None, 'reset': None}
# {'remaining': 852, 'limit': None, 'reset': None}
# {'remaining': 851, 'limit': None, 'reset': None}
# {'remaining': 850, 'limit': None, 'reset': None}
# {'remaining': 849, 'limit': None, 'reset': None}
# {'remaining': 848, 'limit': None, 'reset': None}
# {'remaining': 847, 'limit': None, 'reset': None}
# {'remaining': 846, 'limit': None, 'reset': None}
# {'remaining': 845, 'limit': None, 'reset': None}
# {'remaining': 844, 'limit': None, 'reset': None}
# {'remaining': 843, 'limit': None, 'reset': None}
# {'remaining': 842, 'limit': None, 'reset': None}
# {'remaining': 841, 'limit': None, 'reset': None}
# {'remaining': 840, 'limit': None, 'reset': None}
# {'remaining': 839, 'limit': None, 'reset': None}
# {'remaining': 838, 'limit': None, 'reset': None}
# {'remaining': 837, 'limit': None, 'reset': None}
# {'remaining': 836, 'limit': None, 'reset': None}
# {'remaining': 835, 'limit': None, 'reset': None}
# {'remaining': 834, 'limit': None, 'reset': None}
# {'remaining': 833, 'limit': None, 'reset': None}
# {'remaining': 832, 'limit': None, 'reset': None}
# {'remaining': 831, 'limit': None, 'reset': None}
# {'remaining': 830, 'limit': None, 'reset': None}
# {'remaining': 829, 'limit': None, 'reset': None}
# {'remaining': 828, 'limit': None, 'reset': None}
# {'remaining': 827, 'limit': None, 'reset': None}
# {'remaining': 826, 'limit': None, 'reset': None}
# {'remaining': 825, 'limit': None, 'reset': None}
# {'remaining': 824, 'limit': None, 'reset': None}
# {'remaining': 823, 'limit': None, 'reset': None}
# {'remaining': 822, 'limit': None, 'reset': None}
# {'remaining': 821, 'limit': None, 'reset': None}
# {'remaining': 820, 'limit': None, 'reset': None}
# ...
# {'remaining': 872, 'limit': None, 'reset': None}
# {'remaining': 871, 'limit': None, 'reset': None}
# {'remaining': 870, 'limit': None, 'reset': None}
# {'remaining': 869, 'limit': None, 'reset': None}
# {'remaining': 868, 'limit': None, 'reset': None}
# {'remaining': 867, 'limit': None, 'reset': None}
# {'remaining': 866, 'limit': None, 'reset': None}
# {'remaining': 865, 'limit': None, 'reset': None}
# {'remaining': 864, 'limit': None, 'reset': None}
# {'remaining': 863, 'limit': None, 'reset': None}
# {'remaining': 862, 'limit': None, 'reset': None}
# {'remaining': 861, 'limit': None, 'reset': None}
# {'remaining': 860, 'limit': None, 'reset': None}
# {'remaining': 859, 'limit': None, 'reset': None}
# {'remaining': 858, 'limit': None, 'reset': None}
# {'remaining': 857, 'limit': None, 'reset': None}
# {'remaining': 856, 'limit': None, 'reset': None}
# {'remaining': 855, 'limit': None, 'reset': None}
# {'remaining': 854, 'limit': None, 'reset': None}
# {'remaining': 853, 'limit': None, 'reset': None}
# {'remaining': 852, 'limit': None, 'reset': None}
# {'remaining': 851, 'limit': None, 'reset': None}
# {'remaining': 850, 'limit': None, 'reset': None}
# {'remaining': 849, 'limit': None, 'reset': None}
# {'remaining': 848, 'limit': None, 'reset': None}
# {'remaining': 847, 'limit': None, 'reset': None}
# {'remaining': 846, 'limit': None, 'reset': None}
# {'remaining': 845, 'limit': None, 'reset': None}
# {'remaining': 844, 'limit': None, 'reset': None}
# {'remaining': 843, 'limit': None, 'reset': None}
# {'remaining': 842, 'limit': None, 'reset': None}
# {'remaining': 841, 'limit': None, 'reset': None}
# {'remaining': 840, 'limit': None, 'reset': None}
# {'remaining': 839, 'limit': None, 'reset': None}
# {'remaining': 838, 'limit': None, 'reset': None}
# {'remaining': 837, 'limit': None, 'reset': None}
# {'remaining': 836, 'limit': None, 'reset': None}
# {'remaining': 835, 'limit': None, 'reset': None}
# {'remaining': 834, 'limit': None, 'reset': None}
# {'remaining': 833, 'limit': None, 'reset': None}
# {'remaining': 832, 'limit': None, 'reset': None}
# {'remaining': 831, 'limit': None, 'reset': None}
# {'remaining': 830, 'limit': None, 'reset': None}
# {'remaining': 829, 'limit': None, 'reset': None}
# {'remaining': 828, 'limit': None, 'reset': None}
# {'remaining': 827, 'limit': None, 'reset': None}
# {'remaining': 826, 'limit': None, 'reset': None}
# {'remaining': 825, 'limit': None, 'reset': None}
# {'remaining': 824, 'limit': None, 'reset': None}
# {'remaining': 823, 'limit': None, 'reset': None}
# {'remaining': 822, 'limit': None, 'reset': None}
# {'remaining': 821, 'limit': None, 'reset': None}
# {'remaining': 820, 'limit': None, 'reset': None}
# {'remaining': 819, 'limit': None, 'reset': None}
# {'remaining': 818, 'limit': None, 'reset': None}
# {'remaining': 817, 'limit': None, 'reset': None}
# {'remaining': 816, 'limit': None, 'reset': None}
# {'remaining': 815, 'limit': None, 'reset': None}
# {'remaining': 814, 'limit': None, 'reset': None}
# {'remaining': 813, 'limit': None, 'reset': None}
# {'remaining': 812, 'limit': None, 'reset': None}
# {'remaining': 811, 'limit': None, 'reset': None}
# {'remaining': 810, 'limit': None, 'reset': None}
# {'remaining': 809, 'limit': None, 'reset': None}
# {'remaining': 808, 'limit': None, 'reset': None}
# {'remaining': 807, 'limit': None, 'reset': None}
# {'remaining': 806, 'limit': None, 'reset': None}
# {'remaining': 805, 'limit': None, 'reset': None}
# {'remaining': 804, 'limit': None, 'reset': None}
# {'remaining': 803, 'limit': None, 'reset': None}
# {'remaining': 802, 'limit': None, 'reset': None}
# {'remaining': 801, 'limit': None, 'reset': None}
# {'remaining': 800, 'limit': None, 'reset': None}
# {'remaining': 799, 'limit': None, 'reset': None}
# {'remaining': 798, 'limit': None, 'reset': None}
# {'remaining': 797, 'limit': None, 'reset': None}
# {'remaining': 796, 'limit': None, 'reset': None}
# {'remaining': 795, 'limit': None, 'reset': None}
# {'remaining': 794, 'limit': None, 'reset': None}
# {'remaining': 793, 'limit': None, 'reset': None}
# {'remaining': 792, 'limit': None, 'reset': None}
# {'remaining': 791, 'limit': None, 'reset': None}
# {'remaining': 790, 'limit': None, 'reset': None}
# {'remaining': 789, 'limit': None, 'reset': None}
# {'remaining': 788, 'limit': None, 'reset': None}
# {'remaining': 787, 'limit': None, 'reset': None}
# {'remaining': 786, 'limit': None, 'reset': None}
# {'remaining': 785, 'limit': None, 'reset': None}
# {'remaining': 784, 'limit': None, 'reset': None}
# {'remaining': 783, 'limit': None, 'reset': None}
# {'remaining': 782, 'limit': None, 'reset': None}
# {'remaining': 781, 'limit': None, 'reset': None}
# {'remaining': 780, 'limit': None, 'reset': None}
# {'remaining': 779, 'limit': None, 'reset': None}
# {'remaining': 778, 'limit': None, 'reset': None}
# {'remaining': 777, 'limit': None, 'reset': None}
# {'remaining': 776, 'limit': None, 'reset': None}
# {'remaining': 775, 'limit': None, 'reset': None}
# {'remaining': 774, 'limit': None, 'reset': None}
# {'remaining': 773, 'limit': None, 'reset': None}
# {'remaining': 772, 'limit': None, 'reset': None}
# {'remaining': 771, 'limit': None, 'reset': None}
# {'remaining': 770, 'limit': None, 'reset': None}
# {'remaining': 769, 'limit': None, 'reset': None}
# {'remaining': 768, 'limit': None, 'reset': None}
# {'remaining': 767, 'limit': None, 'reset': None}
# {'remaining': 766, 'limit': None, 'reset': None}
# {'remaining': 765, 'limit': None, 'reset': None}
# {'remaining': 764, 'limit': None, 'reset': None}
# {'remaining': 763, 'limit': None, 'reset': None}
# {'remaining': 762, 'limit': None, 'reset': None}
# {'remaining': 761, 'limit': None, 'reset': None}
# {'remaining': 760, 'limit': None, 'reset': None}
# {'remaining': 759, 'limit': None, 'reset': None}
# {'remaining': 758, 'limit': None, 'reset': None}
# {'remaining': 757, 'limit': None, 'reset': None}
# {'remaining': 756, 'limit': None, 'reset': None}
# {'remaining': 755, 'limit': None, 'reset': None}
# {'remaining': 754, 'limit': None, 'reset': None}
# {'remaining': 753, 'limit': None, 'reset': None}
# {'remaining': 752, 'limit': None, 'reset': None}
# {'remaining': 751, 'limit': None, 'reset': None}
# {'remaining': 750, 'limit': None, 'reset': None}
# {'remaining': 749, 'limit': None, 'reset': None}
# {'remaining': 748, 'limit': None, 'reset': None}
# {'remaining': 747, 'limit': None, 'reset': None}
# {'remaining': 746, 'limit': None, 'reset': None}
# {'remaining': 745, 'limit': None, 'reset': None}
# {'remaining': 744, 'limit': None, 'reset': None}
# {'remaining': 743, 'limit': None, 'reset': None}
# {'remaining': 742, 'limit': None, 'reset': None}
# {'remaining': 741, 'limit': None, 'reset': None}
# {'remaining': 740, 'limit': None, 'reset': None}
# {'remaining': 739, 'limit': None, 'reset': None}
# {'remaining': 738, 'limit': None, 'reset': None}
# {'remaining': 737, 'limit': None, 'reset': None}
# {'remaining': 736, 'limit': None, 'reset': None}
# {'remaining': 735, 'limit': None, 'reset': None}
# {'remaining': 734, 'limit': None, 'reset': None}
# {'remaining': 733, 'limit': None, 'reset': None}
# {'remaining': 732, 'limit': None, 'reset': None}
# {'remaining': 731, 'limit': None, 'reset': None}
# {'remaining': 730, 'limit': None, 'reset': None}
# {'remaining': 729, 'limit': None, 'reset': None}
# {'remaining': 728, 'limit': None, 'reset': None}
# {'remaining': 727, 'limit': None, 'reset': None}
# {'remaining': 726, 'limit': None, 'reset': None}
# {'remaining': 725, 'limit': None, 'reset': None}
# {'remaining': 724, 'limit': None, 'reset': None}
# {'remaining': 723, 'limit': None, 'reset': None}
# {'remaining': 722, 'limit': None, 'reset': None}
# {'remaining': 721, 'limit': None, 'reset': None}
# {'remaining': 720, 'limit': None, 'reset': None}
# {'remaining': 719, 'limit': None, 'reset': None}
# {'remaining': 718, 'limit': None, 'reset': None}
# {'remaining': 717, 'limit': None, 'reset': None}
# {'remaining': 716, 'limit': None, 'reset': None}
# {'remaining': 715, 'limit': None, 'reset': None}
# {'remaining': 714, 'limit': None, 'reset': None}
# {'remaining': 713, 'limit': None, 'reset': None}
# {'remaining': 712, 'limit': None, 'reset': None}
# {'remaining': 711, 'limit': None, 'reset': None}
# {'remaining': 710, 'limit': None, 'reset': None}
# {'remaining': 709, 'limit': None, 'reset': None}
# {'remaining': 708, 'limit': None, 'reset': None}
# {'remaining': 707, 'limit': None, 'reset': None}
# {'remaining': 706, 'limit': None, 'reset': None}
# {'remaining': 705, 'limit': None, 'reset': None}
# {'remaining': 704, 'limit': None, 'reset': None}
# {'remaining': 703, 'limit': None, 'reset': None}
# {'remaining': 702, 'limit': None, 'reset': None}
# {'remaining': 701, 'limit': None, 'reset': None}
# {'remaining': 700, 'limit': None, 'reset': None}
# {'remaining': 699, 'limit': None, 'reset': None}
# {'remaining': 698, 'limit': None, 'reset': None}
# {'remaining': 697, 'limit': None, 'reset': None}
# {'remaining': 696, 'limit': None, 'reset': None}
# {'remaining': 695, 'limit': None, 'reset': None}
# {'remaining': 694, 'limit': None, 'reset': None}
# {'remaining': 693, 'limit': None, 'reset': None}
# {'remaining': 692, 'limit': None, 'reset': None}
# {'remaining': 691, 'limit': None, 'reset': None}
# {'remaining': 690, 'limit': None, 'reset': None}
# {'remaining': 689, 'limit': None, 'reset': None}
# {'remaining': 688, 'limit': None, 'reset': None}
# {'remaining': 687, 'limit': None, 'reset': None}
# {'remaining': 686, 'limit': None, 'reset': None}
# {'remaining': 685, 'limit': None, 'reset': None}
# {'remaining': 684, 'limit': None, 'reset': None}
# {'remaining': 683, 'limit': None, 'reset': None}
# {'remaining': 682, 'limit': None, 'reset': None}
# {'remaining': 681, 'limit': None, 'reset': None}
# {'remaining': 680, 'limit': None, 'reset': None}
# {'remaining': 679, 'limit': None, 'reset': None}
# {'remaining': 678, 'limit': None, 'reset': None}
# {'remaining': 677, 'limit': None, 'reset': None}
# {'remaining': 676, 'limit': None, 'reset': None}
# {'remaining': 675, 'limit': None, 'reset': None}
# {'remaining': 674, 'limit': None, 'reset': None}
# {'remaining': 673, 'limit': None, 'reset': None}
# {'remaining': 672, 'limit': None, 'reset': None}
# {'remaining': 671, 'limit': None, 'reset': None}
# {'remaining': 670, 'limit': None, 'reset': None}
# {'remaining': 669, 'limit': None, 'reset': None}
# {'remaining': 668, 'limit': None, 'reset': None}
# {'remaining': 667, 'limit': None, 'reset': None}
# {'remaining': 666, 'limit': None, 'reset': None}
# {'remaining': 665, 'limit': None, 'reset': None}
# {'remaining': 664, 'limit': None, 'reset': None}
# {'remaining': 663, 'limit': None, 'reset': None}
# {'remaining': 662, 'limit': None, 'reset': None}
# {'remaining': 661, 'limit': None, 'reset': None}
# {'remaining': 660, 'limit': None, 'reset': None}
# {'remaining': 659, 'limit': None, 'reset': None}
# {'remaining': 658, 'limit': None, 'reset': None}
# {'remaining': 657, 'limit': None, 'reset': None}
# {'remaining': 656, 'limit': None, 'reset': None}
# {'remaining': 655, 'limit': None, 'reset': None}
# {'remaining': 654, 'limit': None, 'reset': None}
# {'remaining': 653, 'limit': None, 'reset': None}
# {'remaining': 652, 'limit': None, 'reset': None}
# {'remaining': 651, 'limit': None, 'reset': None}
# {'remaining': 650, 'limit': None, 'reset': None}
# {'remaining': 649, 'limit': None, 'reset': None}
# {'remaining': 648, 'limit': None, 'reset': None}
# {'remaining': 647, 'limit': None, 'reset': None}
# {'remaining': 646, 'limit': None, 'reset': None}
# {'remaining': 645, 'limit': None, 'reset': None}
# {'remaining': 644, 'limit': None, 'reset': None}
# {'remaining': 643, 'limit': None, 'reset': None}
# {'remaining': 642, 'limit': None, 'reset': None}
# {'remaining': 641, 'limit': None, 'reset': None}
# {'remaining': 640, 'limit': None, 'reset': None}
# {'remaining': 639, 'limit': None, 'reset': None}
# {'remaining': 638, 'limit': None, 'reset': None}
# {'remaining': 637, 'limit': None, 'reset': None}
# {'remaining': 636, 'limit': None, 'reset': None}
# {'remaining': 635, 'limit': None, 'reset': None}
# {'remaining': 634, 'limit': None, 'reset': None}
# {'remaining': 633, 'limit': None, 'reset': None}
# {'remaining': 632, 'limit': None, 'reset': None}
# {'remaining': 631, 'limit': None, 'reset': None}
# {'remaining': 630, 'limit': None, 'reset': None}
# {'remaining': 629, 'limit': None, 'reset': None}
# {'remaining': 628, 'limit': None, 'reset': None}
# {'remaining': 627, 'limit': None, 'reset': None}
# {'remaining': 626, 'limit': None, 'reset': None}
# {'remaining': 625, 'limit': None, 'reset': None}
# {'remaining': 624, 'limit': None, 'reset': None}
# {'remaining': 623, 'limit': None, 'reset': None}
# {'remaining': 622, 'limit': None, 'reset': None}
# {'remaining': 621, 'limit': None, 'reset': None}
# {'remaining': 620, 'limit': None, 'reset': None}
# {'remaining': 619, 'limit': None, 'reset': None}
# {'remaining': 618, 'limit': None, 'reset': None}
# {'remaining': 617, 'limit': None, 'reset': None}
# {'remaining': 616, 'limit': None, 'reset': None}
# {'remaining': 615, 'limit': None, 'reset': None}
# {'remaining': 614, 'limit': None, 'reset': None}
# {'remaining': 613, 'limit': None, 'reset': None}
# {'remaining': 612, 'limit': None, 'reset': None}
# {'remaining': 611, 'limit': None, 'reset': None}
# {'remaining': 610, 'limit': None, 'reset': None}
# {'remaining': 609, 'limit': None, 'reset': None}
# {'remaining': 608, 'limit': None, 'reset': None}
# {'remaining': 607, 'limit': None, 'reset': None}
# {'remaining': 606, 'limit': None, 'reset': None}
# {'remaining': 605, 'limit': None, 'reset': None}
# {'remaining': 604, 'limit': None, 'reset': None}
# {'remaining': 603, 'limit': None, 'reset': None}
# {'remaining': 602, 'limit': None, 'reset': None}
# {'remaining': 601, 'limit': None, 'reset': None}
# {'remaining': 600, 'limit': None, 'reset': None}
# {'remaining': 599, 'limit': None, 'reset': None}
# {'remaining': 598, 'limit': None, 'reset': None}
# {'remaining': 597, 'limit': None, 'reset': None}
# {'remaining': 596, 'limit': None, 'reset': None}
# {'remaining': 595, 'limit': None, 'reset': None}
# {'remaining': 594, 'limit': None, 'reset': None}
# {'remaining': 593, 'limit': None, 'reset': None}
# {'remaining': 592, 'limit': None, 'reset': None}
# {'remaining': 591, 'limit': None, 'reset': None}
# {'remaining': 590, 'limit': None, 'reset': None}
# {'remaining': 589, 'limit': None, 'reset': None}
# {'remaining': 588, 'limit': None, 'reset': None}
# {'remaining': 587, 'limit': None, 'reset': None}
# {'remaining': 586, 'limit': None, 'reset': None}
# {'remaining': 585, 'limit': None, 'reset': None}
# {'remaining': 584, 'limit': None, 'reset': None}
# {'remaining': 583, 'limit': None, 'reset': None}
# {'remaining': 582, 'limit': None, 'reset': None}
# {'remaining': 581, 'limit': None, 'reset': None}
# {'remaining': 580, 'limit': None, 'reset': None}
# {'remaining': 579, 'limit': None, 'reset': None}
# {'remaining': 578, 'limit': None, 'reset': None}
# {'remaining': 577, 'limit': None, 'reset': None}
# {'remaining': 576, 'limit': None, 'reset': None}
# {'remaining': 575, 'limit': None, 'reset': None}
# {'remaining': 574, 'limit': None, 'reset': None}
# {'remaining': 573, 'limit': None, 'reset': None}
# {'remaining': 572, 'limit': None, 'reset': None}
# {'remaining': 571, 'limit': None, 'reset': None}
# {'remaining': 570, 'limit': None, 'reset': None}
# {'remaining': 569, 'limit': None, 'reset': None}
# {'remaining': 568, 'limit': None, 'reset': None}
# {'remaining': 567, 'limit': None, 'reset': None}
# {'remaining': 566, 'limit': None, 'reset': None}
# {'remaining': 565, 'limit': None, 'reset': None}
# {'remaining': 564, 'limit': None, 'reset': None}
# {'remaining': 563, 'limit': None, 'reset': None}
# {'remaining': 562, 'limit': None, 'reset': None}
# {'remaining': 561, 'limit': None, 'reset': None}
# {'remaining': 560, 'limit': None, 'reset': None}
# {'remaining': 559, 'limit': None, 'reset': None}
# {'remaining': 558, 'limit': None, 'reset': None}
# {'remaining': 557, 'limit': None, 'reset': None}
# {'remaining': 556, 'limit': None, 'reset': None}
# {'remaining': 555, 'limit': None, 'reset': None}
# {'remaining': 554, 'limit': None, 'reset': None}
# {'remaining': 553, 'limit': None, 'reset': None}
# {'remaining': 552, 'limit': None, 'reset': None}
# {'remaining': 551, 'limit': None, 'reset': None}
# {'remaining': 550, 'limit': None, 'reset': None}
# {'remaining': 549, 'limit': None, 'reset': None}
# {'remaining': 548, 'limit': None, 'reset': None}
# {'remaining': 547, 'limit': None, 'reset': None}

# %%
len(user_responses)
# Out:
# 215219

# %%
# Append any new results to QUERY_RESULTS.

with open(QUERY_RESULTS, "a") as f:
    for user, response in user_responses.items():
        if response == "Not found":
            response = {"found": False}
        else:
            response["found"] = True
        response["id"] = user
        response["queried_time"] = str(datetime.datetime.now())
        json.dump(response, f)
        f.write("\n")

# %% [markdown]
# ## Tweet Queries
#
# Here, we batch-query Tweet IDs to see if they still exist. We skip Tweet IDs for which we know the Tweeter either has a protected or non-existent account.

# %%
# Make sure we don't repeat queries to IDs we have already queried Twitter's API for!
if os.path.exists(TWEET_QUERY_RESULTS):
    with open(TWEET_QUERY_RESULTS, "r") as f:
        for line in f:
            line = line.strip()
            id = json.loads(line)["id"]
            if id in tweets:
                tweets.remove(id)
# Don't query tweets w/ deleted or protected users
if os.path.exists(QUERY_RESULTS):
    with open(QUERY_RESULTS, "r") as f:
        for line in f:
            datum = json.loads(line.strip())
            id = datum["id"]
            if id not in users:
                continue
            if not datum["found"] or datum["protected"]:
                for tweet in users[id].tweets:
                    if tweet.id in tweets:
                        tweets.remove(tweet.id)
print(len(tweets))
# Out:
# 284481

# %%
tweet_responses = {}
for batch_tweets in batch(list(tweets), 100):
    ids = ",".join([str(twt_id) for twt_id in batch_tweets])
    params = {
        "ids": ids,
        "tweet.fields": "id,author_id,withheld"
    }
    r = api.request(f"tweets", params)
    for item in r:
        item["queried_time"] = str(datetime.datetime.now())
        item["found"] = True
        tweet_responses[int(item["id"])] = item
    for twt_id in batch_tweets:
        if twt_id not in tweet_responses:
            tweet_responses[twt_id] = {"found": False, "queried_time": str(datetime.datetime.now())}
    if r.get_quota()["remaining"] < 1:
        print("Ran into quota, sleeping for 15 mins")
        time.sleep(15*60)
    print(r.get_quota()["remaining"])
# Out:
# 899
# 898
# 897
# 896
# 895
# 894
# 893
# 892
# 891
# 890
# 889
# 888
# 887
# 886
# 885
# 884
# 883
# 882
# 881
# 880
# 879
# 878
# 877
# 876
# 875
# 874
# 873
# 872
# 871
# 870
# 869
# 868
# 867
# 866
# 865
# 864
# 863
# 862
# 861
# 860
# 859
# 858
# 857
# 856
# 855
# 854
# 853
# 852
# 851
# 850
# 849
# 848
# 847
# 846
# 845
# 844
# 843
# 842
# 841
# 840
# 839
# 838
# 837
# 836
# 835
# 834
# 833
# 832
# 831
# 830
# 829
# 828
# 827
# 826
# 825
# 824
# 823
# 822
# 821
# 820
# 819
# 818
# 817
# 816
# 815
# 814
# 813
# 812
# 811
# 810
# 809
# 808
# 807
# 806
# 805
# 804
# 803
# 802
# 801
# 800
# 799
# 798
# 797
# 796
# 795
# 794
# 793
# 792
# 791
# 790
# 789
# 788
# 787
# 786
# 785
# 784
# 783
# 782
# 781
# 780
# 779
# 778
# 777
# 776
# 775
# 774
# 773
# 772
# 771
# 770
# 769
# 768
# 767
# 766
# 765
# 764
# 763
# 762
# 761
# 760
# 759
# 758
# 757
# 756
# 755
# 754
# 753
# 752
# 751
# 750
# 749
# 748
# 747
# 746
# 745
# 744
# 743
# 742
# 741
# 740
# 739
# 738
# 737
# 736
# 735
# 734
# 733
# 732
# 731
# 730
# 729
# 728
# 727
# 726
# 725
# 724
# 723
# 722
# 721
# 720
# 719
# 718
# 717
# 716
# 715
# 714
# 713
# 712
# 711
# 710
# 709
# 708
# 707
# 706
# 705
# 704
# 703
# 702
# 701
# 700
# 699
# 698
# 697
# 696
# 695
# 694
# 693
# 692
# 691
# 690
# 689
# 688
# 687
# 686
# 685
# 684
# 683
# 682
# 681
# 680
# 679
# 678
# 677
# 676
# 675
# 674
# 673
# 672
# 671
# 670
# 669
# 668
# 667
# 666
# 665
# 664
# 663
# 662
# 661
# 660
# 659
# 658
# 657
# 656
# 655
# 654
# 653
# 652
# 651
# 650
# 649
# 648
# 647
# 646
# 645
# 644
# 643
# 642
# 641
# 640
# 639
# 638
# 637
# 636
# 635
# 634
# 633
# 632
# 631
# 630
# 629
# 628
# 627
# 626
# 625
# 624
# 623
# 622
# 621
# 620
# 619
# 618
# 617
# 616
# 615
# 614
# 613
# 612
# 611
# 610
# 609
# 608
# 607
# 606
# 605
# 604
# 603
# 602
# 601
# 600
# 599
# 598
# 597
# 596
# 595
# 594
# 593
# 592
# 591
# 590
# 589
# 588
# 587
# 586
# 585
# 584
# 583
# 582
# 581
# 580
# 579
# 578
# 577
# 576
# 575
# 574
# 573
# 572
# 571
# 570
# 569
# 568
# 567
# 566
# 565
# 564
# 563
# 562
# 561
# 560
# 559
# 558
# 557
# 556
# 555
# 554
# 553
# 552
# 551
# 550
# 549
# 548
# 547
# 546
# 545
# 544
# 543
# 542
# 541
# 540
# 539
# 538
# 537
# 536
# 535
# 534
# 533
# 532
# 531
# 530
# 529
# 528
# 527
# 526
# 525
# 524
# 523
# 522
# 521
# 520
# 519
# 518
# 517
# 516
# 515
# 514
# 513
# 512
# 511
# 510
# 509
# 508
# 507
# 506
# 505
# 504
# 503
# 502
# 501
# 500
# 499
# 498
# 497
# 496
# 495
# 494
# 493
# 492
# 491
# 490
# 489
# 488
# 487
# 486
# 485
# 484
# 483
# 482
# 481
# 480
# 479
# 478
# 477
# 476
# 475
# 474
# 473
# 472
# 471
# 470
# 469
# 468
# 467
# 466
# 465
# 464
# 463
# 462
# 461
# 460
# 459
# 458
# 457
# 456
# 455
# 454
# 453
# 452
# 451
# 450
# 449
# 448
# 447
# 446
# 445
# 444
# 443
# 442
# 441
# 440
# 439
# 438
# 437
# 436
# 435
# 434
# 433
# 432
# 431
# 430
# 429
# 428
# 427
# 426
# 425
# 424
# 423
# 422
# 421
# 420
# 419
# 418
# 417
# 416
# 415
# 414
# 413
# 412
# 411
# 410
# 409
# 408
# 407
# 406
# 405
# 404
# 403
# 402
# 401
# 400
# 399
# 398
# 397
# 396
# 395
# 394

# %%
with open(TWEET_QUERY_RESULTS, "a") as f:
    for tweet, response in tweet_responses.items():
        response["id"] = tweet
        json.dump(response, f)
        f.write("\n")
TWEET_QUERY_RESULTS
# Out:
# '../datasets/queried/tokyo/tweets.jsonl'

# %%
len(tweet_responses)
# Out:
# 270000
