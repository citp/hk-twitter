# %%
import pandas as pd
from dacite import from_dict
import json
from dataclasses import dataclass, field
from typing import Optional
import os
CONTROL = True

# %%
@dataclass
class Tweet:
    id: int
    text: str
    created_at: str
    lang: str
    source: str
    retweeted: bool

@dataclass
class User:
    id: int
    screen_name: str
    name: str
    description: Optional[str]
    location: str
    tweets: list[Tweet] = field(default_factory=list)

# %%
directory = "../datasets/users/ia"
filename = "users-ia.json"
if CONTROL:
    directory = "../datasets/users/ia-control"
    filename = "users-ia-control.json"
filepath = os.path.join(directory, filename)
data = {}
tweets = {}
with open(filepath, "r") as f:
    for line in f:
        datum = json.loads(line.strip()) #from_dict(data_class=User, data=json.loads(line.strip()))
        data[datum["id"]] = datum
        for tweet in datum["tweets"]:
            tweet["user_id"] = datum["id"]
            tweets[tweet["id"]] = tweet
        datum["tweets"] = [tweet["id"] for tweet in datum["tweets"]]

# %%
print(len(data))
print(len(tweets))
# Out:
# 11610
# 51617

# %%
users = list(data.values())
users_df = pd.DataFrame.from_dict(users)
users_df["from_ia"] = True
users_df["deleted"] = False
users_df["protected"] = False
users_df["last_query_date"] = None

display(users_df)

tweet_list = list(tweets.values())
tweets_df = pd.DataFrame.from_dict(tweet_list)
tweets_df["from_ia"] = True
tweets_df["user_deleted"] = False
tweets_df["deleted"] = False
tweets_df["user_protected"] = False

tweets_df["last_query_date"] = None
display(tweets_df)
# Out:
#                id     screen_name                     name  \
# 0      2351009236        AKokolli           Arbnor Kokolli
# 1       593232251       nic_mar98          Nicole Marino 🌙
# 2        78455847     typhanieluv                ObamaCrat
# 3      3313384270  Laurettamylove             laurettalove
# 4        29094983  Beauty_TheBeat     ⚜️Creole Seasoning⚜️
# ...           ...             ...                      ...
# 11605   467874137   PhilLiubicich           Phil Liubicich
# 11606   199606358   WhtvrJeffSaid  Jeffrey Skinner-Perkins
# 11607    30258547        Starcode       Dave O'Connor, PhD
# 11608   854918461    NikiHatzidis            Niki Hatzidis
# 11609    34661669    laurenkeasey       Lauren Jade Keasey
#
#                                              description  \
# 0                                                   None
# 1      "Art is not what I create. What I create is Ch...
# 2      LOVES LIFE, Politics, Music, Movies & Broadway...
# 3      I AM LOVE-A Health-Nutrition Vegan & Fitness E...
# 4      Your Destani⚜️Private Pilot | First In Flight✈...
# ...                                                  ...
# 11605  NYC Fireman (ret) E Pluribus Unum 🇺🇸 Non Imped...
# 11606                                            nobody.
# 11607                                               None
# 11608  Award Nominated Playwright/Features Writer @ O...
# 11609  Artist, designer, digital maven & party girl e...
#
#                       location  \
# 0                New York City
# 1                New York City
# 2                NEW YORK CITY
# 3                NEW YORK CITY
# 4                New York City
# ...                        ...
# 11605            New York City
# 11606            New York City
# 11607            New York City
# 11608  New York City, New York
# 11609            New York City
#
#                                                   tweets  from_ia  deleted  \
# 0             [1134983435523694592, 1134944327829004295]     True    False
# 1      [1134983448119205898, 1163533794416181248, 111...     True    False
# 2      [1134977685162201089, 1134909141850513411, 116...     True    False
# 3      [1134977907435196417, 1134799980877811712, 113...     True    False
# 4      [1134985943713140736, 1135001009682436096, 116...     True    False
# ...                                                  ...      ...      ...
# 11605                              [1138923866691166213]     True    False
# 11606                              [1138922998470070272]     True    False
# 11607                              [1138924953032626177]     True    False
# 11608                              [1138927670941691904]     True    False
# 11609                              [1138922507766030336]     True    False
#
#        protected last_query_date
# 0          False            None
# 1          False            None
# 2          False            None
# 3          False            None
# 4          False            None
# ...          ...             ...
# 11605      False            None
# 11606      False            None
# 11607      False            None
# 11608      False            None
# 11609      False            None
#
# [11610 rows x 10 columns]
#                         id                                               text  \
# 0      1134983435523694592  RT @FootballFactly: No opposition player has c...
# 1      1134944327829004295  RT @LFC: A moment we'll never forget.\n\n#SixT...
# 2      1134983448119205898  RT @_justmateo_: They made their reservation j...
# 3      1163533794416181248  RT @Pathryn34: Remember when Sam Winchester to...
# 4      1117763116501278722  @nicosicko I just checked mine and it said the...
# ...                    ...                                                ...
# 51612  1138923866691166213                       @FreakinLibs The end of porn
# 51613  1138922998470070272  The U.S. Department of State should issue a Tr...
# 51614  1138924953032626177  Had a great time at Pier 17 last night seeing ...
# 51615  1138927670941691904  Fillmore is helping me read scripts for @athen...
# 51616  1138922507766030336  Oww you caught me reading my book upside down ...
#
#                       created_at lang  \
# 0      2019-06-02 00:41:52+00:00   en
# 1      2019-06-01 22:06:28+00:00   en
# 2      2019-06-02 00:41:55+00:00   en
# 3      2019-08-19 19:30:48+00:00   en
# 4      2019-04-15 12:14:28+00:00   en
# ...                          ...  ...
# 51612  2019-06-12 21:39:44+00:00   en
# 51613  2019-06-12 21:36:17+00:00   en
# 51614  2019-06-12 21:44:03+00:00   en
# 51615  2019-06-12 21:54:51+00:00   en
# 51616  2019-06-12 21:34:20+00:00   en
#
#                                                   source  retweeted  \
# 0      <a href="http://twitter.com/download/android" ...      False
# 1      <a href="http://twitter.com/download/android" ...      False
# 2      <a href="http://twitter.com/download/iphone" r...      False
# 3      <a href="http://twitter.com/download/iphone" r...      False
# 4      <a href="http://twitter.com/download/iphone" r...      False
# ...                                                  ...        ...
# 51612  <a href="http://twitter.com" rel="nofollow">Tw...      False
# 51613  <a href="http://www.facebook.com/twitter" rel=...      False
# 51614  <a href="https://tapbots.com/software/tweetbot...      False
# 51615  <a href="http://instagram.com" rel="nofollow">...      False
# 51616  <a href="http://instagram.com" rel="nofollow">...      False
#
#           user_id  from_ia  user_deleted  deleted  user_protected  \
# 0      2351009236     True         False    False           False
# 1      2351009236     True         False    False           False
# 2       593232251     True         False    False           False
# 3       593232251     True         False    False           False
# 4       593232251     True         False    False           False
# ...           ...      ...           ...      ...             ...
# 51612   467874137     True         False    False           False
# 51613   199606358     True         False    False           False
# 51614    30258547     True         False    False           False
# 51615   854918461     True         False    False           False
# 51616    34661669     True         False    False           False
#
#       last_query_date
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 51612            None
# 51613            None
# 51614            None
# 51615            None
# 51616            None
#
# [51617 rows x 12 columns]

# %%
user_lookup_filename = "queried_users_ia.jsonl"
tweet_lookup_filename = "queried_users_tweets_ia.jsonl"
if CONTROL:
    user_lookup_filename = "control_" + user_lookup_filename
    tweet_lookup_filename = "control_" + tweet_lookup_filename

with open(user_lookup_filename, "r") as f:
    for line in f:
        line = line.strip()
        data = json.loads(line)
        #print(data["protected"])
        #print(data.keys())
        users_df.loc[users_df["id"] == data["id"], "deleted"] = not data["found"]
        users_df.loc[users_df["id"] == data["id"], "last_query_date"] = data["queried_time"]
        if data["found"]:
            users_df.loc[users_df["id"] == data["id"], "protected"] = data["protected"]
            tweets_df.loc[tweets_df["user_id"] == data["id"], "user_protected"] = data["protected"]
        else:
            tweets_df.loc[tweets_df["user_id"] == data["id"], "user_deleted"] = not data["found"]

# %%
queried_users = {}
with open(tweet_lookup_filename, "r") as f:
    for line in f:
        line = line.strip()
        data = json.loads(line)
        #print(data["protected"])
        tweets_df.loc[tweets_df["id"] == data["id"], "deleted"] = not data["found"]
        tweets_df.loc[tweets_df["id"] == data["id"], "last_query_date"] = data["queried_time"]

# %%
sum(list(users_df["deleted"] | users_df["protected"]))/len(users_df)
# Out:
# 0.13755383290267012

# %%
users_out_filename = "users_ia_hk.pkl"
tweets_out_filename = "tweets_ia_hk.pkl"
if CONTROL:
    users_out_filename = "control_" + users_out_filename
    tweets_out_filename = "control_" + tweets_out_filename
users_df.to_pickle(users_out_filename)
tweets_df.to_pickle(tweets_out_filename)

# %%
# Out:
#                         id                                               text  \
# 0      1101628887279128576  I just hope the size chart was right! https://...
# 1      1101631420659724288  @sakurakharel @BuffordIanah @irmaroxas3 @grabe...
# 2      1101455255668088832  RT @irmaroxas3: @sakurakharel @BuffordIanah @g...
# 3      1101457453516873729  RT @LiesesMarryHK: @Elj1329 @aldubeth02 @pinky...
# 4      1101415388833701889  RT @grabesila: @sakurakharel @BuffordIanah @ir...
# ...                    ...                                                ...
# 86882  1095572048082944001  RT @vboykis: Confused about all the different ...
# 86883  1095564561237737472  【ドラゴンボールZ ドッカンバトル】\nドッカンバトルはついに4周年！\n「力属性ガシャ」開...
# 86884  1095396839430311936                    ごちそうさま♡ https://t.co/uB8LusQUqS
# 86885  1095391588136542208         RT @WANIMAL912: 收工 https://t.co/grL9n19Haj
# 86886  1095393735624388609  #国产 #视频 #苗条 #嫩妹 #巨乳 #圆乳 #垂乳 #超乳 #下垂 #乳摇 #turnd...
#
#                       created_at lang  \
# 0      2019-03-01 23:42:48+00:00   en
# 1      2019-03-01 23:52:52+00:00   en
# 2      2019-03-01 12:12:51+00:00   en
# 3      2019-03-01 12:21:35+00:00   en
# 4      2019-03-01 09:34:26+00:00   nl
# ...                          ...  ...
# 86882  2019-02-13 06:35:05+00:00   en
# 86883  2019-02-13 06:05:20+00:00   ja
# 86884  2019-02-12 18:58:52+00:00   ja
# 86885  2019-02-12 18:38:00+00:00   ja
# 86886  2019-02-12 18:46:32+00:00  und
#
#                                                   source  retweeted  \
# 0      <a href="https://www.shopperapproved.com/" rel...      False
# 1      <a href="http://twitter.com/download/android" ...      False
# 2      <a href="http://twitter.com/download/android" ...      False
# 3      <a href="http://twitter.com/download/android" ...      False
# 4      <a href="http://twitter.com/download/android" ...      False
# ...                                                  ...        ...
# 86882  <a href="http://twitter.com/download/android" ...      False
# 86883  <a href="http://twitter.com" rel="nofollow">Tw...      False
# 86884  <a href="http://twitter.com/download/android" ...      False
# 86885  <a href="http://twitter.com/download/iphone" r...      False
# 86886  <a href="http://twitter.com/download/iphone" r...      False
#
#                    user_id  from_ia  user_deleted  deleted  user_protected  \
# 0                 20838690     True         False    False           False
# 1       734509989855961089     True         False    False           False
# 2       734509989855961089     True         False    False           False
# 3       734509989855961089     True         False    False           False
# 4       734509989855961089     True         False    False           False
# ...                    ...      ...           ...      ...             ...
# 86882            205276657     True         False    False           False
# 86883           4859048519     True         False    False           False
# 86884            774330398     True         False    False           False
# 86885   973162772547727360     True         False    False           False
# 86886  1070033264159555584     True          True    False           False
#
#                   last_query_date
# 0      2021-12-27 11:44:26.230899
# 1      2021-12-27 11:42:01.525895
# 2      2021-12-27 11:49:01.190461
# 3      2021-12-27 11:45:08.141071
# 4      2021-12-27 11:44:48.986565
# ...                           ...
# 86882  2021-12-27 11:46:06.634750
# 86883  2021-12-27 11:49:36.685321
# 86884  2021-12-27 11:44:07.721638
# 86885  2021-12-27 11:50:06.616330
# 86886                        None
#
# [86887 rows x 12 columns]
